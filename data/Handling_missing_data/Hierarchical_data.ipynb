# %%
import pandas as pd
from rdflib import Graph, RDFS, URIRef, RDF
from collections import defaultdict

# %%
# === Load RDF Graph ===
g = Graph()
g.parse("graph_odor.ttl", format="ttl")

# === Build Subclass Hierarchy: child -> set of parents ===
subclass_map = defaultdict(set)
instance_map = defaultdict(set)

for child, _, parent in g.triples((None, RDFS.subClassOf, None)):
    child_label = child.split('#')[-1].split('/')[-1].lower()
    parent_label = parent.split('#')[-1].split('/')[-1].lower()
    subclass_map[child_label].add(parent_label)

# Map individuals to classes
for instance, _, cls in g.triples((None, RDF.type, None)):
    if cls != RDFS.Class:  # <-- skip RDF class declarations
        instance_label = instance.split('#')[-1].split('/')[-1].lower()
        class_label = cls.split('#')[-1].split('/')[-1].lower()
        instance_map[instance_label].add(class_label)

# === Recursively find all ancestors ===
def get_all_parents(term, visited=None):
    if visited is None:
        visited = set()
    for parent in subclass_map.get(term, []):
        if parent not in visited:
            visited.add(parent)
            get_all_parents(parent, visited)
    return visited

# === Load CSV ===
df = pd.read_csv("C:/Users/suman/OneDrive/Bureau/Internship_Study/GNN_On_OdorPrediction/data/raw_data/OdorCAS_preprocessed.csv")
df.columns = [col.lower() for col in df.columns]

# Get list of descriptor columns (excluding 'cas_number')
descriptor_cols = list(df.columns)
descriptor_cols.remove("cas_number")

# Track Update
all_new_descriptors = set()
modifications_log = []
total_added_descriptors = 0
total_modified_cas = 0
excluded_descriptors = {"odeur"}

# === Enrich Descriptors Per Row ===
for index, row in df.iterrows():
    cas_number = row["cas_number"]
    active_descriptors = {col for col in descriptor_cols if row[col] == 1}
    enriched_descriptors = set()

    # Get all parent descriptors for each active descriptor
    for desc in active_descriptors:
        # 1. Add class parents
        enriched_descriptors.update(get_all_parents(desc))

        # 2. Add rdf:type class if desc is an instance
        for parent_class in instance_map.get(desc, []):
            enriched_descriptors.add(parent_class)
            enriched_descriptors.update(get_all_parents(parent_class))

    # List of newly added descriptors
    added_descriptors = []
    for new_desc in enriched_descriptors:
        if new_desc not in excluded_descriptors:  # Skip excluded descriptors
            if new_desc not in df.columns:
                all_new_descriptors.add(new_desc)
                df[new_desc] = 0  # Initialize new column with 0
                
            # If the descriptor wasn't already set to 1, set it to 1
            if df.at[index, new_desc] == 0:
                df.at[index, new_desc] = 1
                added_descriptors.append(new_desc)

    # Log modification if any new descriptors were added
    if added_descriptors:
        modifications_log.append({
            "cas_number": cas_number,
            "new_descriptors_added": added_descriptors
        })
        total_added_descriptors += len(added_descriptors)
        total_modified_cas += 1

# === Save the updated CSV ===
df.to_csv("Hierarchy_OdorCAS.csv", index=False)
print("Updated 'OdorCAS_preprocessed.csv'")

# Show the modification summary
print(f"\nNumber of CAS modified: {total_modified_cas}")
print(f"Number of descriptors added: {total_added_descriptors}")

# Show and save modification log if any changes were made
if modifications_log:
    print("\n=== Modification Summary ===")
    for entry in modifications_log:
        print(f"CAS {entry['cas_number']} ➜ added descriptors: {', '.join(entry['new_descriptors_added'])}")
    
    # Save the log to a file
    log_df = pd.DataFrame(modifications_log)
    log_df.to_csv("LOG_label_added.csv", index=False)
    print("\nLog saved.")
else:
    print("\nNo changes were made to descriptors.")


if all_new_descriptors:
    print("\n=== New Columns Added to the CSV ===")
    for col in sorted(all_new_descriptors):
        print(col)
    print(f"\nTotal new descriptor columns added: {len(all_new_descriptors)}")
else:
    print("\nNo new columns were added to the CSV.")

new_descriptor_list = sorted(all_new_descriptors)
print("List of new descriptor columns:\n", new_descriptor_list)
# Out:
# Updated 'OdorCAS_preprocessed.csv'
#
# Number of CAS modified: 3627
# Number of descriptors added: 23863
#
# === Modification Summary ===
# CAS 50-70-4 ➜ added descriptors: empyreumatique, cuit, sucre_cuit
# CAS 51-67-2 ➜ added descriptors: empyreumatique, chimique, vegetal, soufre
# CAS 56-12-2 ➜ added descriptors: cuit, empyreumatique
# CAS 56-85-9 ➜ added descriptors: empyreumatique, lactique, malte, creme, torrefie, gras
# CAS 56-86-0 ➜ added descriptors: empyreumatique, cereale, malte, cuit, fermentaire
# CAS 57-06-7 ➜ added descriptors: racine, crucifere, terreux, vegetal, soufre, legume
# CAS 57-10-3 ➜ added descriptors: animal, graisse_animale, aldehyde, vegetal_vert, vegetal
# CAS 57-50-1 ➜ added descriptors: empyreumatique, cuit, sucre_cuit
# CAS 58-08-2 ➜ added descriptors: mineral, metal
# CAS 58-86-6 ➜ added descriptors: empyreumatique, cuit, fume, phenole, sucre_cuit
# CAS 60-01-5 ➜ added descriptors: lactique, fermentaire
# CAS 60-12-8 ➜ added descriptors: empyreumatique, fleur_d_arbuste, malte, cuit, cereale, mielle
# CAS 64-04-0 ➜ added descriptors: amine, chimique
# CAS 64-17-5 ➜ added descriptors: solvant, phenole, chimique, frais
# CAS 64-18-6 ➜ added descriptors: empyreumatique, malte, cuit, crucifere, chimique, cereale, vegetal, soufre, legume
# CAS 64-19-7 ➜ added descriptors: chimique, fermentaire
# CAS 65-85-0 ➜ added descriptors: amine, boise, doux
# CAS 66-25-1 ➜ added descriptors: animal, fruit_a_pepins, vegetal_vert, vegetal, aldehyde_frais
# CAS 67-47-0 ➜ added descriptors: empyreumatique, lactique, aldehyde, cuit, vegetal_sec, fermentaire, vegetal_vert, vegetal, aldehyde_frais, frais, doux, sucre_cuit
# CAS 67-63-0 ➜ added descriptors: solvant, fermentaire, phenole, medicinal, chimique, frais
# CAS 67-64-1 ➜ added descriptors: fruit_a_pepins, chimique, frais, fruite
# CAS 67-68-5 ➜ added descriptors: lactique, malte, alliace, boise, moisi, fermentaire, terreux, cereale, vegetal, soufre, legume
# CAS 69-72-7 ➜ added descriptors: fruit_sec, gras, fruite, oleagineux
# CAS 71-23-8 ➜ added descriptors: solvant, alcool_blanc, fruit_a_pepins, phenole, fruit_sec, gras, boissons_alcoolisees, oleagineux, chimique, medicinal, frais
# CAS 71-36-3 ➜ added descriptors: boissons_alcoolisees, boise, fruit_exotique, alcool_de_fut, chimique, fruite, gras
# CAS 71-41-0 ➜ added descriptors: empyreumatique, malte, boissons_alcoolisees, cuit, boise, boisson_fermentee, chimique, frais, floral, gras
# CAS 74-93-1 ➜ added descriptors: animal, empyreumatique, lactique, cuit, fermentaire, crucifere, vegetal, gras
# CAS 75-04-7 ➜ added descriptors: amine, chimique
# CAS 75-07-0 ➜ added descriptors: solvant, fermentaire, vegetal_vert, chimique, vegetal, gras
# CAS 75-18-3 ➜ added descriptors: vegetal_vert, plante_aromatique, amine, malte, alliace, racine, crucifere, terreux, cereale, vegetal, frais
# CAS 75-31-0 ➜ added descriptors: amine, chimique
# CAS 75-33-2 ➜ added descriptors: animal, empyreumatique, poulailler, cuit, alliace, vegetal, legume
# CAS 75-50-3 ➜ added descriptors: amine, animal, gras
# CAS 76-09-5 ➜ added descriptors: empyreumatique, cereale, malte, cuit
# CAS 76-22-2 ➜ added descriptors: menthe, phenole, medicinal, chimique, vegetal_vert, vegetal, frais
# CAS 76-49-3 ➜ added descriptors: aldehyde, phenole, vegetal_vert, gras, bois, menthe, resineux, medicinal, chimique, vegetal, frais, aldehyde_frais, fruite
# CAS 76-50-6 ➜ added descriptors: animal, menthe, fermentaire, urine_de_chat, phenole, medicinal, chimique, vegetal_vert, vegetal, frais, fruite, pied
# CAS 77-53-2 ➜ added descriptors: animal, bois, musque, balsamique, resineux, vegetal_vert, vegetal
# CAS 77-54-3 ➜ added descriptors: bois, balsamique, resineux, vegetal, floral, doux
# CAS 77-70-3 ➜ added descriptors: empyreumatique, cuit, oleagineux, fruit_sec, doux, fruite, gras, sucre_cuit
# CAS 77-74-7 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 77-83-8 ➜ added descriptors: mielle, fruit_rouge
# CAS 77-90-7 ➜ added descriptors: boissons_alcoolisees, aldehyde, fermentaire, boisson_fermentee, vegetal_vert, chimique, vegetal, aldehyde_frais, floral, frais, gras
# CAS 78-35-3 ➜ added descriptors: citronne, fleur_d_arbuste, frais
# CAS 78-36-4 ➜ added descriptors: citronne, frais, fruit_noir, fruit_exotique
# CAS 78-37-5 ➜ added descriptors: fleur_du_jardin, boise, fleur_d_arbre, phenole, medicinal, mielle, chimique, floral
# CAS 78-59-1 ➜ added descriptors: animal, bois, menthe, vegetal_sec, fermentaire, resineux, phenole, medicinal, chimique, vegetal_vert, vegetal, frais
# CAS 78-69-3 ➜ added descriptors: bois, fleur_d_arbuste, aldehyde, vegetal_sec, vegetal_vert, vegetal, aldehyde_frais, fleur_du_jardin, fruite
# CAS 78-70-6 ➜ added descriptors: citronne, bois, fleur_d_arbuste, vegetal_vert, vegetal, frais, fruit_noir, baie, fruite, gras
# CAS 78-81-9 ➜ added descriptors: amine, lactique, fermentaire
# CAS 78-83-1 ➜ added descriptors: boissons_alcoolisees, boise, solvant, balsamique, fermentaire, boisson_fermentee, alcool_de_fut, chimique, frais, floral, doux, fruite
# CAS 78-84-2 ➜ added descriptors: vegetal_vert, vegetal, aldehyde_frais, gras
# CAS 78-85-3 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, frais, floral
# CAS 78-92-2 ➜ added descriptors: lactone, fruit_a_noyau, fruite
# CAS 78-93-3 ➜ added descriptors: menthe, solvant, phenole, medicinal, vegetal_vert, vegetal, frais
# CAS 78-96-6 ➜ added descriptors: amine
# CAS 78-98-8 ➜ added descriptors: empyreumatique, boissons_alcoolisees, cuit, boise, solvant, balsamique, alcool_de_fut, chimique, frais, sucre_cuit
# CAS 79-09-4 ➜ added descriptors: acetique, chimique, fermentaire
# CAS 79-20-9 ➜ added descriptors: boise, balsamique, fermentaire, boisson_fermentee, vegetal_vert, boissons_alcoolisees, alcool_de_fut, chimique, vegetal, floral
# CAS 79-31-2 ➜ added descriptors: pied, gras, fermentaire
# CAS 79-42-5 ➜ added descriptors: empyreumatique, cuit
# CAS 79-69-6 ➜ added descriptors: fleur_du_jardin, fruit_rouge
# CAS 79-70-9 ➜ added descriptors: empyreumatique, cuit, fruit_cuit, fleur_du_jardin, sucre_cuit
# CAS 79-77-6 ➜ added descriptors: fleur_du_jardin
# CAS 79-78-7 ➜ added descriptors: animal, aldehyde, balsamique, phenole, vegetal_vert, vegetal, aldehyde_frais, fleur_du_jardin, frais, gras
# CAS 79-89-0 ➜ added descriptors: animal, fleur_du_jardin
# CAS 79-92-5 ➜ added descriptors: aldehyde, phenole, vegetal_vert, plante_aromatique, gras, bois, resineux, medicinal, chimique, vegetal, frais, aldehyde_frais, fruite
# CAS 80-25-1 ➜ added descriptors: citronne, aldehyde, agrume, vegetal_vert, vegetal, aldehyde_frais, fruite, gras
# CAS 80-26-2 ➜ added descriptors: citronne, fleur_d_arbuste, aldehyde, vegetal_vert, vegetal, frais, aldehyde_frais, fruite, gras
# CAS 80-27-3 ➜ added descriptors: floral, citronne, aldehyde, vegetal_vert, phenole, pin, gras, bois, resineux, vegetal, frais, fleur_du_jardin, aldehyde_frais
# CAS 80-54-6 ➜ added descriptors: vegetal_vert, vegetal, frais, fleur_du_jardin, epice
# CAS 80-56-8 ➜ added descriptors: bois, menthe, aldehyde, resineux, phenole, medicinal, chimique, vegetal_vert, vegetal, aldehyde_frais, fruite, gras
# CAS 80-57-9 ➜ added descriptors: menthe, vegetal_vert, plante_aromatique, vegetal, phenole, medicinal, chimique, frais
# CAS 80-59-1 ➜ added descriptors: empyreumatique, legume, cuit, terreux, vegetal, fruit_cuit, sucre_cuit
# CAS 80-62-6 ➜ added descriptors: chimique
# CAS 80-71-7 ➜ added descriptors: empyreumatique, cuit, boise, balsamique, doux, sucre_cuit
# CAS 81-14-1 ➜ added descriptors: animal, musque, aldehyde, vegetal_vert, vegetal
# CAS 81-15-2 ➜ added descriptors: animal, vegetal_vert, aldehyde, vegetal, musque
# CAS 83-34-1 ➜ added descriptors: chimique, musque, produit_petrolier
# CAS 83-66-9 ➜ added descriptors: animal, vegetal_vert, vegetal, musque, fermentaire
# CAS 85-91-6 ➜ added descriptors: boissons_alcoolisees, fermentaire, boisson_fermentee, fleur_d_arbre, chimique, mielle
# CAS 86-26-0 ➜ added descriptors: fleur_d_arbuste, floral
# CAS 87-05-8 ➜ added descriptors: oleagineux, fruit_sec, fruite, gras
# CAS 87-19-4 ➜ added descriptors: fleur_du_jardin, camphre, menthe, aldehyde, phenole, medicinal, chimique, vegetal_vert, vegetal, frais, aldehyde_frais, gras
# CAS 87-20-7 ➜ added descriptors: fleur_du_jardin, mineral, metal, aldehyde, marin, vegetal_vert, vegetal, frais, aldehyde_frais, gras
# CAS 87-22-9 ➜ added descriptors: mineral, fleur_d_arbuste, metal, boise, phenole, chimique, fleur_du_jardin, doux
# CAS 87-25-2 ➜ added descriptors: camphre, fruit_a_pepins, fleur_d_arbre, phenole, vegetal_vert, mielle, plante_aromatique, medicinal, chimique, vegetal, frais
# CAS 87-41-2 ➜ added descriptors: lactique, boise, vegetal_sec, balsamique, vegetal_vert, fruit_sec, gras, fruit_exotique, oleagineux, vegetal, frais, fruite
# CAS 87-44-5 ➜ added descriptors: oleagineux, phenole, medicinal, chimique, fruit_sec, floral, fruite, gras
# CAS 87-55-8 ➜ added descriptors: empyreumatique, lactique, cuit, boise, balsamique, doux, gras, sucre_cuit
# CAS 87-91-2 ➜ added descriptors: empyreumatique, boissons_alcoolisees, cuit, fermentaire, boisson_fermentee, chimique, floral, doux, sucre_cuit
# CAS 88-09-5 ➜ added descriptors: boissons_alcoolisees, boise, balsamique, alcool_de_fut, chimique, doux
# CAS 88-14-2 ➜ added descriptors: empyreumatique, cuit, doux, sucre_cuit
# CAS 88-15-3 ➜ added descriptors: empyreumatique, legume, alliace, oleagineux, fruit_sec, vegetal, fruite, gras
# CAS 88-29-9 ➜ added descriptors: animal, vegetal_vert, vegetal, musque
# CAS 88-41-5 ➜ added descriptors: aldehyde, fruit_a_pepins, pomme, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 88-60-8 ➜ added descriptors: phenole
# CAS 88-69-7 ➜ added descriptors: empyreumatique, bois, boissons_alcoolisees, balsamique, alcool_de_fut, fume, chimique, vegetal, frais, doux, soufre
# CAS 88-84-6 ➜ added descriptors: fromage, empyreumatique, bois, lactique, fermentaire, fume, phenole, vegetal, floral
# CAS 89-43-0 ➜ added descriptors: fleur_du_jardin, fruite, fleur_d_arbre, mielle
# CAS 89-47-4 ➜ added descriptors: animal, menthe, fermentaire, urine_de_chat, vegetal_vert, vegetal, frais, pied
# CAS 89-48-5 ➜ added descriptors: vegetal_sec, vegetal_vert, plante_aromatique, vegetal, frais
# CAS 89-71-4 ➜ added descriptors: fruit_a_pepins, fleur_d_arbre, mielle, doux, fruite
# CAS 89-74-7 ➜ added descriptors: fleur_d_arbre, vegetal_vert, plante_aromatique, vegetal, frais
# CAS 89-78-1 ➜ added descriptors: vegetal_vert, plante_aromatique, vegetal, frais
# CAS 89-79-2 ➜ added descriptors: aldehyde, vegetal_vert, plante_aromatique, vegetal, frais, phenole, chimique, aldehyde_frais, fruite, gras
# CAS 89-80-5 ➜ added descriptors: vegetal_vert, plante_aromatique, vegetal, frais
# CAS 89-81-6 ➜ added descriptors: aldehyde, phenole, chimique, vegetal_vert, vegetal, frais, plante_aromatique, aldehyde_frais, gras
# CAS 89-82-7 ➜ added descriptors: metal, aldehyde, phenole, vegetal_vert, plante_aromatique, mineral, fruit_noir, gras, fruit_rouge, medicinal, aldehyde_frais, chimique, vegetal, baie
# CAS 89-83-8 ➜ added descriptors: menthe, aldehyde, vegetal_vert, vegetal, frais, plante_aromatique, aldehyde_frais, gras
# CAS 89-88-3 ➜ added descriptors: empyreumatique, bois, fume, vegetal_vert, plante_aromatique, vegetal, phenole, legume
# CAS 90-02-8 ➜ added descriptors: camphre, menthe, boise, phenole, chimique, vegetal_vert, vegetal, frais
# CAS 90-05-1 ➜ added descriptors: viande_fumee, empyreumatique, cuit, balsamique, fume, chimique, doux
# CAS 90-12-0 ➜ added descriptors: menthe, produit_petrolier, fermentaire, phenole, vegetal_vert, vegetal, frais
# CAS 90-17-5 ➜ added descriptors: fleur_d_arbuste, aldehyde, boise, vegetal_vert, vegetal, doux, gras
# CAS 90-42-6 ➜ added descriptors: floral, aldehyde, vegetal_vert, plante_aromatique, vegetal, frais, fleur_du_jardin, chimique, epice, aldehyde_frais, gras
# CAS 90-87-9 ➜ added descriptors: fleur_du_jardin, boise, fermentaire, vegetal_vert, fruit_sec, mielle, gras, fruit_a_coque, legume, moisi, oleagineux, crucifere, vegetal, frais, soufre
# CAS 91-01-0 ➜ added descriptors: fleur_d_arbuste, aldehyde, vegetal_vert, vegetal, aldehyde_frais, floral, frais, gras
# CAS 91-02-1 ➜ added descriptors: fermentaire
# CAS 91-10-1 ➜ added descriptors: viande_fumee, empyreumatique, lactique, cuit, fume, chimique, floral
# CAS 91-16-7 ➜ added descriptors: lactique, boise, balsamique, fermentaire
# CAS 91-19-0 ➜ added descriptors: amine
# CAS 91-20-3 ➜ added descriptors: boise, bois, vegetal
# CAS 91-22-5 ➜ added descriptors: animal, boise, vegetal_sec, fruite, balsamique, oleagineux, fermentaire, lactone, phenole, vegetal, frais, fruit_sec, doux, gras, soufre
# CAS 91-50-9 ➜ added descriptors: floral, fleur_d_arbre, mielle, fleur_du_jardin, doux, fruite
# CAS 91-51-0 ➜ added descriptors: floral, fleur_d_arbre, vegetal_vert, mielle, vegetal, fleur_du_jardin, doux, fruite
# CAS 91-57-6 ➜ added descriptors: gras
# CAS 91-60-1 ➜ added descriptors: lactique, fermentaire, fruit_sec, gras, animal, empyreumatique, grille, cuit, moisi, oleagineux, terreux, chimique, fruite
# CAS 91-61-2 ➜ added descriptors: phenole, musque, boise
# CAS 91-62-3 ➜ added descriptors: musque, produit_petrolier, boise, vegetal_sec, balsamique, lactone, chimique, vegetal, frais, doux, coumarine
# CAS 91-64-5 ➜ added descriptors: boise, vegetal_sec, balsamique, lactone, vegetal, frais
# CAS 91-87-2 ➜ added descriptors: fleur_du_jardin, citronne, fleur_d_arbuste, agrume, vegetal_vert, vegetal, frais, floral, fruite
# CAS 92-48-8 ➜ added descriptors: lactique, boise, vegetal_sec, patisserie, balsamique, phenole, fruit_sec, epice, gras, fruit_exotique, empyreumatique, cuit, oleagineux, lactone, medicinal, vegetal, frais, chimique, fruite
# CAS 92-52-4 ➜ added descriptors: floral, citronne, fleur_d_arbuste, boise, fleur_d_arbre, phenole, vegetal_vert, mielle, doux, epice, agrume, medicinal, chimique, frais, fleur_du_jardin, vegetal, fruite
# CAS 92-68-2 ➜ added descriptors: fleur_du_jardin, chimique
# CAS 93-04-9 ➜ added descriptors: produit_petrolier, fruit_a_noyau, fruite, fruit_a_pepins, fleur_d_arbre, chimique, mielle
# CAS 93-08-3 ➜ added descriptors: produit_petrolier, fleur_d_arbre, chimique, mielle, fruite
# CAS 93-15-2 ➜ added descriptors: fleur_du_jardin, fermentaire, medicinal, chimique, vegetal, floral
# CAS 93-16-3 ➜ added descriptors: fleur_du_jardin, empyreumatique, citronne, bois, agrume, fume, phenole, medicinal, chimique, vegetal, frais, fruite
# CAS 93-18-5 ➜ added descriptors: produit_petrolier, aldehyde, fruit_a_pepins, fleur_d_arbre, vegetal_vert, chimique, mielle, vegetal, doux, fruite, gras
# CAS 93-19-6 ➜ added descriptors: vegetal_sec, foret, terreux, phenole, vegetal, legume
# CAS 93-28-7 ➜ added descriptors: poivre, phenole, medicinal, chimique, fleur_du_jardin
# CAS 93-29-8 ➜ added descriptors: empyreumatique, fume, phenole, brule, medicinal, chimique, fleur_du_jardin
# CAS 93-51-6 ➜ added descriptors: animal, empyreumatique, malte, cuit, torrefie, balsamique, fume, sucre_cuit
# CAS 93-53-8 ➜ added descriptors: fleur_d_arbuste, aldehyde, vegetal_vert, vegetal, aldehyde_frais, fleur_du_jardin, gras
# CAS 93-54-9 ➜ added descriptors: mielle, boise
# CAS 93-55-0 ➜ added descriptors: fleur_d_arbuste, aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, gras, fruit_rouge
# CAS 93-58-3 ➜ added descriptors: fleur_d_arbre, vegetal_vert, fruit_sec, doux, gras, fruit_a_coque, fruit_rouge, menthe, amande_amere, oleagineux, medicinal, vegetal, frais, fruite
# CAS 93-60-7 ➜ added descriptors: aldehyde, vegetal_sec, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 93-89-0 ➜ added descriptors: camphre, fermentaire, fruit_a_pepins, phenole, chimique, vegetal_vert, vegetal, frais, plante_aromatique, fruit_rouge
# CAS 93-91-4 ➜ added descriptors: fleur_d_arbuste, floral, doux
# CAS 93-92-5 ➜ added descriptors: fleur_d_arbuste, oleagineux, fermentaire, vegetal_vert, fruit_sec, vegetal, frais, floral, gras
# CAS 94-02-0 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, fruit_a_pepins, fruit_sec, fruit_cuit, gras, fruit_a_coque, fruit_rouge, empyreumatique, produit_petrolier, amande_amere, cuit, oleagineux, chimique, floral, sucre_cuit
# CAS 94-13-3 ➜ added descriptors: fume, empyreumatique, phenole, fleur_d_arbuste, floral
# CAS 94-30-4 ➜ added descriptors: boise, vegetal_sec, balsamique, fruit_a_pepins, vegetal_vert, plante_aromatique, legume, fruit_rouge, coumarine, bois, racine, lactone, terreux, vegetal, frais
# CAS 94-46-2 ➜ added descriptors: vegetal_vert, vegetal, frais, boise
# CAS 94-47-3 ➜ added descriptors: fleur_d_arbuste, boise, vegetal_vert, chimique, mielle, vegetal, frais, doux
# CAS 94-48-4 ➜ added descriptors: fleur_d_arbuste, boise, balsamique, fleur_d_arbre, floral
# CAS 94-50-8 ➜ added descriptors: boise, doux
# CAS 94-59-7 ➜ added descriptors: vegetal_vert, plante_aromatique, vegetal, frais, anise
# CAS 94-86-0 ➜ added descriptors: lactique, vegetal_sec, balsamique, vegetal, frais
# CAS 95-15-8 ➜ added descriptors: chimique, frais, soufre
# CAS 95-16-9 ➜ added descriptors: empyreumatique, oleagineux, fruit_sec, chimique, vegetal, fruite, gras
# CAS 95-20-5 ➜ added descriptors: chimique, produit_petrolier
# CAS 95-21-6 ➜ added descriptors: vegetal_sec, fermentaire, fruit_sec, gras, empyreumatique, acetique, cuit, oleagineux, chimique, vegetal, floral, fruite
# CAS 95-41-0 ➜ added descriptors: lactique, fleur_d_arbuste, aldehyde, vegetal_vert, plante_aromatique, vegetal, aldehyde_frais, gras
# CAS 95-48-7 ➜ added descriptors: animal, aldehyde, fermentaire, chimique, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 95-65-8 ➜ added descriptors: fume, empyreumatique, phenole
# CAS 95-87-4 ➜ added descriptors: viande_fumee, empyreumatique, produit_petrolier, fermentaire, fume
# CAS 96-04-8 ➜ added descriptors: empyreumatique, boissons_alcoolisees, cuit, boise, balsamique, fermentaire, alcool_de_fut, chimique, doux, gras, sucre_cuit
# CAS 96-08-2 ➜ added descriptors: vegetal_vert, vegetal, frais, menthe
# CAS 96-17-3 ➜ added descriptors: lactique, boise, solvant, balsamique, fruit_sec, doux, empyreumatique, boissons_alcoolisees, cuit, torrefie, oleagineux, alcool_de_fut, medicinal, chimique, frais, lacte, sucre_cuit
# CAS 96-22-0 ➜ added descriptors: chimique, frais, solvant
# CAS 96-26-4 ➜ added descriptors: vegetal_vert, plante_aromatique, vegetal, frais
# CAS 96-48-0 ➜ added descriptors: empyreumatique, lactique, fruit_a_noyau, cuit, lactone, doux, sucre_cuit
# CAS 96-54-8 ➜ added descriptors: empyreumatique, aldehyde, fume, phenole, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 97-41-6 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, boissons_alcoolisees, aldehyde, fermentaire, boisson_fermentee, vegetal_vert, chimique, vegetal, aldehyde_frais, frais, gras
# CAS 97-42-7 ➜ added descriptors: fleur_du_jardin, aldehyde, boise, balsamique, fruit_a_pepins, vegetal_vert, plante_aromatique, gras, boissons_alcoolisees, alcool_de_fut, crucifere, chimique, vegetal, frais, floral, aldehyde_frais, moutarde, soufre
# CAS 97-45-0 ➜ added descriptors: lactique, metal, boise, foret, vegetal_vert, plante_aromatique, mineral, doux, empyreumatique, cuit, terreux, vegetal, frais, sucre_cuit
# CAS 97-53-0 ➜ added descriptors: viande_fumee, empyreumatique, poivre, cuit, viande_cuite, fume, medicinal, chimique
# CAS 97-54-1 ➜ added descriptors: fleur_du_jardin, poivre, medicinal, chimique
# CAS 97-61-0 ➜ added descriptors: lactique, gras, fermentaire
# CAS 97-62-1 ➜ added descriptors: boissons_alcoolisees, boise, solvant, balsamique, alcool_de_fut, phenole, chimique, medicinal, frais, vegetal, soufre, legume
# CAS 97-63-2 ➜ added descriptors: chimique
# CAS 97-64-3 ➜ added descriptors: empyreumatique, lactique, cuit, solvant, chimique, frais, gras, fruit_exotique, sucre_cuit
# CAS 97-85-8 ➜ added descriptors: chimique, frais, solvant
# CAS 97-87-0 ➜ added descriptors: lactique, boissons_alcoolisees, moisi, peponide, fermentaire, boisson_fermentee, fruit_a_pepins, vegetal_vert, chimique, vegetal, frais, floral, fruit_rouge
# CAS 97-89-2 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, frais
# CAS 97-95-0 ➜ added descriptors: phenole, chimique, medicinal, frais, solvant, fermentaire
# CAS 97-96-1 ➜ added descriptors: empyreumatique, malte, solvant, torrefie, vegetal_vert, chimique, vegetal
# CAS 97-99-4 ➜ added descriptors: empyreumatique, chou, cuit, oleagineux, crucifere, fruit_sec, vegetal, doux, fruite, gras, soufre, sucre_cuit
# CAS 98-00-0 ➜ added descriptors: empyreumatique, malte, cuit, solvant, fermentaire, phenole, medicinal, frais, cereale, fruite, sucre_cuit
# CAS 98-01-1 ➜ added descriptors: empyreumatique, malte, amande_amere, cuit, oleagineux, sucre_cuit, fruit_sec, cereale, fruite, gras
# CAS 98-02-2 ➜ added descriptors: animal, empyreumatique, poulailler, cuit, oleagineux, fume, phenole, chimique, fruit_sec, fruite, legumes_cuits
# CAS 98-03-3 ➜ added descriptors: doux, fruite, fruit_rouge
# CAS 98-52-2 ➜ added descriptors: animal, fermentaire, phenole, medicinal, chimique, vegetal_vert, vegetal, frais, plante_aromatique
# CAS 98-53-3 ➜ added descriptors: animal, musque, vegetal_vert, plante_aromatique, vegetal, frais, phenole
# CAS 98-54-4 ➜ added descriptors: animal, boise, foret, terreux, phenole, vegetal
# CAS 98-55-5 ➜ added descriptors: citronne, fleur_d_arbuste, aldehyde, vegetal_vert, phenole, gras, bois, vegetal, frais, fruite
# CAS 98-85-1 ➜ added descriptors: floral, fleur_d_arbuste, phenole, vegetal_vert, fruit_sec, gras, fruit_a_coque, menthe, produit_petrolier, amande_amere, oleagineux, vegetal, fleur_du_jardin, fruite
# CAS 98-86-2 ➜ added descriptors: fleur_d_arbuste, boise, vegetal_sec, balsamique, fleur_d_arbre, fruit_sec, gras, fruit_rouge, amande_amere, oleagineux, lactone, vegetal, frais, floral
# CAS 98-89-5 ➜ added descriptors: lactique, metal, fermentaire, vegetal_vert, vegetal, frais, mineral
# CAS 99-48-9 ➜ added descriptors: bois, aldehyde, boise, vegetal_vert, plante_aromatique, vegetal, frais, chimique, aldehyde_frais, gras, anise
# CAS 99-49-0 ➜ added descriptors: boise, vegetal_sec, balsamique, vegetal_vert, plante_aromatique, doux, legume, coumarine, bois, racine, lactone, terreux, vegetal, frais
# CAS 99-50-3 ➜ added descriptors: boise, doux
# CAS 99-72-9 ➜ added descriptors: aldehyde, fermentaire, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 99-75-2 ➜ added descriptors: fleur_d_arbre, frais
# CAS 99-83-2 ➜ added descriptors: poivre, citronne, aldehyde, vegetal_vert, vegetal, aldehyde_frais, epice, fruite, gras
# CAS 99-85-4 ➜ added descriptors: citronne, aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 99-86-5 ➜ added descriptors: citronne, aldehyde, phenole, vegetal_vert, plante_aromatique, gras, bois, resineux, chimique, vegetal, frais, aldehyde_frais, fruite
# CAS 99-87-6 ➜ added descriptors: citronne, legume_vert, vert_pyrazique, vegetal_vert, plante_aromatique, vegetal, fruite, gras, legume
# CAS 99-89-8 ➜ added descriptors: empyreumatique, chimique
# CAS 99-91-2 ➜ added descriptors: vegetal, fleur_d_arbuste, vegetal_sec
# CAS 99-93-4 ➜ added descriptors: fleur_d_arbre, fleur_d_arbuste, floral, boise
# CAS 99-96-7 ➜ added descriptors: fruit_sec, gras, fruite, oleagineux
# CAS 100-06-1 ➜ added descriptors: fleur_d_arbuste, boise, fleur_d_arbre, floral, frais, fruit_rouge
# CAS 100-09-4 ➜ added descriptors: chimique
# CAS 100-42-5 ➜ added descriptors: amande_amere, boise, oleagineux, fruit_sec, chimique, fruite, gras, fruit_a_coque
# CAS 100-51-6 ➜ added descriptors: fleur_d_arbuste, amande_amere, boise, oleagineux, fruit_rouge, fruit_sec, gras, fruit_a_coque
# CAS 100-52-7 ➜ added descriptors: amande_amere, oleagineux, fruit_sec, floral, gras, fruit_rouge
# CAS 100-53-8 ➜ added descriptors: empyreumatique, racine, crucifere, vegetal_vert, plante_aromatique, vegetal, frais, terreux, legume
# CAS 100-55-0 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 100-66-3 ➜ added descriptors: produit_petrolier, solvant, vegetal_vert, chimique, plante_aromatique, frais, vegetal, epice, anise
# CAS 100-68-5 ➜ added descriptors: empyreumatique, chimique, frais, torrefie
# CAS 100-69-6 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 100-71-0 ➜ added descriptors: aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 100-84-5 ➜ added descriptors: floral, fleur_du_jardin
# CAS 100-86-7 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, boise, vegetal_vert, vegetal, epice, chimique, frais, gras
# CAS 101-39-3 ➜ added descriptors: phenole, medicinal, chimique
# CAS 101-41-7 ➜ added descriptors: amande_amere, oleagineux, fruit_sec, mielle, gras, fruit_a_coque
# CAS 101-48-4 ➜ added descriptors: fleur_du_jardin, bois, fleur_d_arbuste, aldehyde, boise, moisi, fermentaire, vegetal_vert, vegetal, aldehyde_frais, frais, fruite, gras
# CAS 101-49-5 ➜ added descriptors: floral, vegetal_vert, mielle, vegetal, fleur_du_jardin, frais
# CAS 101-81-5 ➜ added descriptors: floral, mineral, fleur_d_arbuste, metal, fruit_a_pepins, vegetal_vert, chimique, vegetal, frais, fleur_du_jardin, fruite, gras
# CAS 101-82-6 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 101-84-8 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, metal, chimique, vegetal_vert, vegetal, mineral, frais
# CAS 101-85-9 ➜ added descriptors: fleur_d_arbuste, boise, phenole, medicinal, chimique, vegetal_vert, vegetal, frais
# CAS 101-86-0 ➜ added descriptors: fleur_d_arbuste, aldehyde, vegetal_vert, vegetal, aldehyde_frais, gras
# CAS 101-94-0 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, boise, mielle, doux
# CAS 101-97-3 ➜ added descriptors: empyreumatique, malte, fleur_d_arbuste, boise, cuit, caramel, torrefie, fermentaire, mielle, frais, sucre_cuit
# CAS 102-04-5 ➜ added descriptors: fleur_d_arbuste, chimique, mielle, fruite, fruit_rouge
# CAS 102-13-6 ➜ added descriptors: empyreumatique, lactique, malte, boise, balsamique, torrefie, lacte, mielle
# CAS 102-16-9 ➜ added descriptors: empyreumatique, lactique, fleur_d_arbuste, malte, torrefie, lacte, mielle
# CAS 102-17-0 ➜ added descriptors: vegetal_sec, phenole, plante_aromatique, mielle, vegetal_vert, doux, epice, legume, coumarine, bois, racine, lactone, terreux, chimique, vegetal, frais, floral
# CAS 102-19-2 ➜ added descriptors: empyreumatique, lactique, fleur_d_arbuste, malte, boise, fruite, torrefie, lacte, mielle
# CAS 102-20-5 ➜ added descriptors: fleur_d_arbuste, boise, vegetal_sec, phenole, vegetal_vert, mielle, epice, empyreumatique, malte, torrefie, medicinal, vegetal, chimique, frais, fruite
# CAS 102-22-7 ➜ added descriptors: fleur_du_jardin, mielle, floral, doux
# CAS 102-69-2 ➜ added descriptors: amine, chimique
# CAS 102-76-1 ➜ added descriptors: phenole, chimique, lactique, gras
# CAS 103-05-9 ➜ added descriptors: bois, fleur_d_arbuste, boise, fleur_d_arbre, vegetal_vert, vegetal, fleur_du_jardin, gras
# CAS 103-07-1 ➜ added descriptors: fleur_d_arbuste, aldehyde, boise, vegetal_vert, vegetal, frais, fleur_du_jardin, gras
# CAS 103-09-3 ➜ added descriptors: aldehyde, moisi, fermentaire, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 103-13-9 ➜ added descriptors: empyreumatique, lactique, cuit, doux, gras, sucre_cuit
# CAS 103-25-3 ➜ added descriptors: boissons_alcoolisees, boise, fermentaire, boisson_fermentee, chimique, mielle, doux
# CAS 103-26-4 ➜ added descriptors: boise, fruit_exotique, phenole, medicinal, chimique, fruit_rouge
# CAS 103-28-6 ➜ added descriptors: fleur_d_arbuste, floral, gras
# CAS 103-36-6 ➜ added descriptors: boise, fruit_a_noyau, phenole, medicinal, chimique, vegetal_vert, floral, vegetal, frais
# CAS 103-37-7 ➜ added descriptors: fleur_d_arbuste, fruit_a_noyau, fruit_a_pepins, lactone, floral, fruit_rouge
# CAS 103-38-8 ➜ added descriptors: floral, aldehyde, boise, fermentaire, fruit_a_pepins, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 103-41-3 ➜ added descriptors: boise, fruit_rouge
# CAS 103-45-7 ➜ added descriptors: empyreumatique, fleur_d_arbuste, malte, boise, torrefie, fermentaire, vegetal_vert, mielle, vegetal, frais
# CAS 103-48-0 ➜ added descriptors: fleur_d_arbuste, fruit_a_noyau, boise, fermentaire, lactone, vegetal_vert, vegetal, doux, mielle, gras
# CAS 103-50-4 ➜ added descriptors: fleur_d_arbuste, boise, moisi, fermentaire, chimique, floral, fruit_rouge
# CAS 103-52-6 ➜ added descriptors: boissons_alcoolisees, fermentaire, boisson_fermentee, vegetal_vert, chimique, vegetal, frais, fruit_rouge
# CAS 103-53-7 ➜ added descriptors: fleur_d_arbuste, boise, foret, fleur_d_arbre, terreux, vegetal_vert, vegetal, doux
# CAS 103-54-8 ➜ added descriptors: fleur_d_arbuste, boise, phenole, medicinal, mielle, chimique, fruite
# CAS 103-56-0 ➜ added descriptors: boise, fruit_a_pepins, vegetal_vert, vegetal, frais, fruit_rouge
# CAS 103-58-2 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, fruit_a_noyau, boise, fruit_a_pepins, mielle, fruit_cuit, fruit_noir, fruit_rouge, empyreumatique, malte, cuit, lactone, chimique, cereale, floral, baie, sucre_cuit
# CAS 103-59-3 ➜ added descriptors: amande_amere, boise, oleagineux, phenole, fruit_sec, medicinal, chimique, gras, fruit_a_coque
# CAS 103-60-6 ➜ added descriptors: fleur_d_arbuste, fruit_a_pepins, vegetal_vert, mielle, vegetal, frais
# CAS 103-61-7 ➜ added descriptors: boissons_alcoolisees, boise, alcool_de_fut, boisson_fermentee, fermentaire, phenole, chimique, medicinal, floral, doux
# CAS 103-64-0 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, frais, floral
# CAS 103-74-2 ➜ added descriptors: empyreumatique, vegetal_vert, vegetal, frais
# CAS 103-79-7 ➜ added descriptors: amande_amere, oleagineux, fruit_sec, doux, fruite, gras, fruit_a_coque
# CAS 103-82-2 ➜ added descriptors: empyreumatique, lactique, fleur_d_arbuste, malte, musque, vegetal_sec, torrefie, cacao, lacte, vegetal, mielle
# CAS 103-93-5 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, frais
# CAS 103-95-7 ➜ added descriptors: fleur_du_jardin, fermentaire, vegetal_vert, vegetal, fruite, gras
# CAS 104-09-6 ➜ added descriptors: floral, fleur_d_arbuste, oleagineux, vegetal_vert, fruit_sec, vegetal, frais, fleur_du_jardin, gras, fruit_rouge
# CAS 104-20-1 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, balsamique, fleur_d_arbre, mielle, fruit_rouge
# CAS 104-21-2 ➜ added descriptors: lactique, boise, vegetal_sec, fruit_a_noyau, legume, fruit_rouge, bois, racine, lactone, terreux, vegetal, frais, floral
# CAS 104-27-8 ➜ added descriptors: lactique, fleur_d_arbuste, boise, vegetal_sec, balsamique, fruit_sec, gras, fruit_rouge, fruit_a_coque, amande_amere, oleagineux, lactone, vegetal, frais, floral
# CAS 104-45-0 ➜ added descriptors: aldehyde, legume_vert, boise, vegetal_sec, balsamique, fermentaire, boisson_fermentee, vegetal_vert, plante_aromatique, anise, gras, legume, coumarine, bois, malte, boissons_alcoolisees, racine, lactone, terreux, chimique, vegetal, frais, aldehyde_frais, levure
# CAS 104-46-1 ➜ added descriptors: boise, vegetal_sec, balsamique, vegetal_vert, plante_aromatique, phenole, anise, epice, coumarine, legume, bois, racine, lactone, terreux, chimique, vegetal, frais
# CAS 104-50-7 ➜ added descriptors: aldehyde, boise, vegetal_sec, fruit_a_noyau, balsamique, vegetal_vert, fruit_sec, fruit_exotique, empyreumatique, oleagineux, vegetal, frais
# CAS 104-53-0 ➜ added descriptors: boise, peponide, vegetal_vert, vegetal, doux, gras
# CAS 104-54-1 ➜ added descriptors: boise, phenole, medicinal, mielle, chimique, fleur_du_jardin, vegetal_vert, vegetal, frais
# CAS 104-55-2 ➜ added descriptors: floral, bois, boise, vegetal_vert, medicinal, vegetal, mielle, phenole, chimique, gras
# CAS 104-57-4 ➜ added descriptors: amande_amere, vegetal_sec, oleagineux, fruit_rouge, fruit_sec, vegetal, doux, gras, fruit_a_coque
# CAS 104-61-0 ➜ added descriptors: lactique, boise, vegetal_sec, oleagineux, balsamique, lactone, fruit_sec, vegetal, frais, fruite, fruit_exotique, coumarine
# CAS 104-62-1 ➜ added descriptors: floral, fleur_d_arbuste, aldehyde, soufre, banane, crucifere, vegetal_vert, vegetal, aldehyde_frais, fleur_du_jardin, frais, fruite, gras, fruit_exotique, legume
# CAS 104-64-3 ➜ added descriptors: boise, phenole, medicinal, mielle, chimique, fleur_du_jardin, epice
# CAS 104-65-4 ➜ added descriptors: aldehyde, boise, fermentaire, boisson_fermentee, phenole, vegetal_vert, doux, gras, boissons_alcoolisees, chimique, medicinal, vegetal, fleur_du_jardin, aldehyde_frais, frais
# CAS 104-67-6 ➜ added descriptors: lactique, fruit_a_noyau, boise, vegetal_sec, balsamique, fruit_sec, doux, fruit_exotique, coumarine, oleagineux, vegetal, frais
# CAS 104-87-0 ➜ added descriptors: boise, medicinal, chimique, fruit_rouge
# CAS 104-90-5 ➜ added descriptors: lactique, fermentaire, boisson_fermentee, fruit_sec, gras, legume, empyreumatique, malte, boissons_alcoolisees, oleagineux, chimique, vegetal, frais, floral, fruite
# CAS 104-93-8 ➜ added descriptors: fleur_du_jardin, produit_petrolier, fruite, oleagineux, fleur_d_arbre, medicinal, chimique, vegetal_vert, floral, vegetal, frais, plante_aromatique, fruit_sec, gras
# CAS 105-01-1 ➜ added descriptors: boissons_alcoolisees, fermentaire, boisson_fermentee, chimique, fruit_exotique
# CAS 105-13-5 ➜ added descriptors: fleur_du_jardin, lactique, fleur_d_arbuste, boise, vegetal_sec, vegetal_vert, plante_aromatique, anise, epice, legume, fruit_rouge, empyreumatique, bois, malte, racine, torrefie, terreux, vegetal, frais, fruite
# CAS 105-21-5 ➜ added descriptors: lactique, boise, vegetal_sec, balsamique, fruit_sec, gras, fruit_exotique, empyreumatique, cuit, oleagineux, vegetal, frais, floral, fruite, sucre_cuit
# CAS 105-37-3 ➜ added descriptors: boissons_alcoolisees, boise, solvant, balsamique, boisson_fermentee, fruit_a_pepins, alcool_de_fut, chimique, frais, floral, fruit_exotique
# CAS 105-43-1 ➜ added descriptors: vegetal_vert, lactique, vegetal, fermentaire
# CAS 105-45-3 ➜ added descriptors: vegetal_vert, vegetal
# CAS 105-46-4 ➜ added descriptors: chimique, frais, fruit_exotique
# CAS 105-53-3 ➜ added descriptors: vegetal_vert, vegetal, frais, fruit_exotique, fruit_a_pepins
# CAS 105-54-4 ➜ added descriptors: boissons_alcoolisees, boise, solvant, balsamique, alcool_de_fut, fruit_a_pepins, fruit_exotique, chimique
# CAS 105-57-7 ➜ added descriptors: solvant, oleagineux, vegetal_vert, fruit_sec, vegetal, frais, chimique, fruite, gras
# CAS 105-66-8 ➜ added descriptors: animal, fruit_a_noyau, solvant, lactone, vegetal_vert, chimique, vegetal, frais, gras, fruit_exotique
# CAS 105-67-9 ➜ added descriptors: fume, empyreumatique, phenole
# CAS 105-68-0 ➜ added descriptors: peponide, fruit_a_pepins, vegetal_vert, vegetal
# CAS 105-79-3 ➜ added descriptors: fruit_a_noyau, fruit_a_pepins, pomme, lactone, vegetal_vert, vegetal, frais
# CAS 105-82-8 ➜ added descriptors: fleur_du_jardin, aldehyde, racine, crucifere, vegetal_vert, terreux, vegetal, floral, aldehyde_frais, gras, soufre
# CAS 105-85-1 ➜ added descriptors: citronne, cucurbitacee, fleur_d_arbuste, aldehyde, fruit_a_noyau, fruit_a_pepins, vegetal_vert, gras, legume, lactone, vegetal, aldehyde_frais, frais
# CAS 105-86-2 ➜ added descriptors: fleur_d_arbuste, fruit_a_noyau, fruit_a_pepins, lactone, fleur_d_arbre, vegetal_vert, mielle, doux, vegetal
# CAS 105-87-3 ➜ added descriptors: fleur_d_arbuste, aldehyde, boise, balsamique, fermentaire, boisson_fermentee, vegetal_vert, doux, gras, boissons_alcoolisees, alcool_de_fut, chimique, vegetal, aldehyde_frais, frais, fruite
# CAS 105-89-5 ➜ added descriptors: fleur_du_jardin, citronne, fleur_d_arbuste, vegetal_vert, plante_aromatique, fruit_sec, doux, gras, fruit_a_coque, amande_amere, oleagineux, agrume, vegetal, frais, floral, fruite
# CAS 105-90-8 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, mielle, doux, gras
# CAS 105-91-9 ➜ added descriptors: empyreumatique, cuit, vegetal_vert, vegetal, fruit_cuit, frais, sucre_cuit
# CAS 105-95-3 ➜ added descriptors: animal, musque, balsamique, vegetal_vert, vegetal
# CAS 106-02-5 ➜ added descriptors: lactique, fleur_d_arbuste, musque, boise, vegetal_sec, balsamique, doux, legume, bois, racine, lactone, terreux, vegetal, frais, floral
# CAS 106-18-3 ➜ added descriptors: aldehyde, oleagineux, vegetal_vert, fruit_sec, vegetal, gras
# CAS 106-21-8 ➜ added descriptors: animal, citronne, fleur_d_arbuste, fermentaire, vegetal_vert, phenole, vegetal, fruite
# CAS 106-22-9 ➜ added descriptors: animal, fleur_d_arbuste, phenole, vegetal_vert, vegetal, frais
# CAS 106-23-0 ➜ added descriptors: citronne, fleur_d_arbuste, vegetal_vert, vegetal, frais, aldehyde_frais, fruite, gras
# CAS 106-24-1 ➜ added descriptors: citronne, fleur_d_arbuste, fruit_a_noyau, lactone, vegetal_vert, plante_aromatique, vegetal, frais
# CAS 106-25-2 ➜ added descriptors: citronne, fleur_d_arbre, vegetal_vert, mielle, vegetal
# CAS 106-26-3 ➜ added descriptors: citronne, frais, zeste_agrume, fruite
# CAS 106-27-4 ➜ added descriptors: fruit_a_noyau, peponide, fruit_a_pepins, lactone, vegetal_vert, vegetal, frais
# CAS 106-28-5 ➜ added descriptors: fleur_du_jardin
# CAS 106-29-6 ➜ added descriptors: fleur_d_arbuste, fruit_a_noyau, lactone, vegetal_vert, vegetal, fruit_rouge
# CAS 106-30-9 ➜ added descriptors: boise, balsamique, fermentaire, boisson_fermentee, vegetal_vert, gras, fruit_exotique, fruit_rouge, boissons_alcoolisees, alcool_de_fut, chimique, vegetal, frais, floral
# CAS 106-32-1 ➜ added descriptors: aldehyde, fruit_a_noyau, boise, balsamique, boisson_fermentee, fruit_a_pepins, vegetal_vert, fruit_exotique, boissons_alcoolisees, alcool_de_fut, lactone, terreux, chimique, vegetal, floral
# CAS 106-33-2 ➜ added descriptors: boissons_alcoolisees, aldehyde, boise, balsamique, alcool_de_fut, vegetal_vert, chimique, vegetal, gras
# CAS 106-35-4 ➜ added descriptors: vegetal_vert, lactique, vegetal, frais, fermentaire
# CAS 106-36-5 ➜ added descriptors: boissons_alcoolisees, fermentaire, boisson_fermentee, vegetal_vert, vegetal, frais, floral
# CAS 106-44-5 ➜ added descriptors: fleur_d_arbre, floral, fleur_du_jardin
# CAS 106-45-6 ➜ added descriptors: empyreumatique, vegetal_vert, vegetal, frais
# CAS 106-65-0 ➜ added descriptors: boissons_alcoolisees, aldehyde, boise, balsamique, alcool_de_fut, boisson_fermentee, fermentaire, fruit_exotique, vegetal_vert, chimique, vegetal, frais, gras
# CAS 106-68-3 ➜ added descriptors: lactique, fleur_d_arbuste, aldehyde, boise, vegetal_vert, vegetal, floral, aldehyde_frais, gras
# CAS 106-70-7 ➜ added descriptors: viande_fumee, empyreumatique, lactique, fruit_a_noyau, solvant, fruit_a_pepins, fume, lactone, phenole, chimique, frais, fruit_rouge
# CAS 106-72-9 ➜ added descriptors: cucurbitacee, aldehyde, peponide, vegetal_vert, vegetal, aldehyde_frais, fruite, gras, legume
# CAS 106-73-0 ➜ added descriptors: fruit_a_pepins, vegetal_vert, vegetal, frais, fleur_du_jardin
# CAS 107-02-8 ➜ added descriptors: amande_amere, oleagineux, fruit_rouge, fruit_sec, doux, fruite, gras, fruit_a_coque
# CAS 107-03-9 ➜ added descriptors: empyreumatique, cuit, crucifere, vegetal, legume
# CAS 107-18-6 ➜ added descriptors: crucifere, vegetal, soufre, legume
# CAS 107-19-7 ➜ added descriptors: floral, fleur_du_jardin
# CAS 107-31-3 ➜ added descriptors: fruit_a_noyau
# CAS 107-74-4 ➜ added descriptors: fleur_d_arbuste, moisi, fermentaire, terreux, vegetal_vert, vegetal, frais, fleur_du_jardin
# CAS 107-75-5 ➜ added descriptors: peponide, vegetal_vert, vegetal, frais, fleur_du_jardin, fruite
# CAS 107-85-7 ➜ added descriptors: amine, chimique
# CAS 107-86-8 ➜ added descriptors: amande_amere, oleagineux, fruit_rouge, vegetal_vert, fruit_sec, vegetal, frais, gras
# CAS 107-87-9 ➜ added descriptors: boissons_alcoolisees, solvant, boisson_fermentee, chimique, frais, floral, fruit_exotique
# CAS 107-92-6 ➜ added descriptors: chimique, gras, fermentaire
# CAS 107-93-7 ➜ added descriptors: lactique
# CAS 108-10-1 ➜ added descriptors: aldehyde, vegetal_vert, chimique, vegetal, frais, aldehyde_frais, gras
# CAS 108-11-2 ➜ added descriptors: solvant, phenole, medicinal, chimique, frais
# CAS 108-21-4 ➜ added descriptors: frais, solvant, fruit_exotique, fruit_a_pepins
# CAS 108-22-5 ➜ added descriptors: chou, solvant, fermentaire, crucifere, vegetal_vert, chimique, vegetal, frais, soufre, legume
# CAS 108-29-2 ➜ added descriptors: aldehyde, vegetal_sec, balsamique, vegetal_vert, fruit_sec, gras, fruit_exotique, empyreumatique, malte, oleagineux, torrefie, lactone, vegetal, frais, aldehyde_frais, fruite
# CAS 108-39-4 ➜ added descriptors: animal, chimique
# CAS 108-40-7 ➜ added descriptors: empyreumatique
# CAS 108-46-3 ➜ added descriptors: lactique, fleur_d_arbuste, boise, fruite, balsamique, oleagineux, fermentaire, fruit_sec, floral, doux, gras
# CAS 108-47-4 ➜ added descriptors: fume, empyreumatique, vegetal_vert, vegetal, frais
# CAS 108-48-5 ➜ added descriptors: amine, empyreumatique, malte, cuit, oleagineux, torrefie, fermentaire, fruit_sec, chimique, cereale, vegetal, fruite, gras
# CAS 108-50-9 ➜ added descriptors: empyreumatique, lactique, malte, cuit, solvant, oleagineux, fermentaire, lacte, chimique, frais, cereale, fruit_sec, fruite, gras
# CAS 108-64-5 ➜ added descriptors: metal, fruit_a_pepins, fruit_exotique, agrume, vegetal_vert, vegetal, frais, mineral
# CAS 108-68-9 ➜ added descriptors: empyreumatique, doux, boise
# CAS 108-82-7 ➜ added descriptors: chimique, solvant
# CAS 108-83-8 ➜ added descriptors: mineral, boissons_alcoolisees, metal, boise, solvant, balsamique, alcool_de_fut, fruit_a_pepins, vegetal_vert, chimique, vegetal, frais, doux
# CAS 108-84-9 ➜ added descriptors: fruit_exotique
# CAS 108-89-4 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 108-93-0 ➜ added descriptors: menthe, medicinal, chimique, vegetal_vert, vegetal, frais
# CAS 108-94-1 ➜ added descriptors: solvant, vegetal_vert, chimique, vegetal, frais, plante_aromatique
# CAS 108-95-2 ➜ added descriptors: chimique, soufre
# CAS 108-98-5 ➜ added descriptors: empyreumatique, cuit, chimique, vegetal, legume
# CAS 108-99-6 ➜ added descriptors: oleagineux, vegetal_vert, fruit_sec, vegetal, frais, fruite, gras
# CAS 109-05-7 ➜ added descriptors: amine, lactique, legume_vert, chimique, vegetal, legume
# CAS 109-06-8 ➜ added descriptors: oleagineux, fruit_sec, fruite, gras
# CAS 109-08-0 ➜ added descriptors: lactique, fermentaire, vegetal_vert, fruit_sec, doux, gras, empyreumatique, malte, oleagineux, lacte, vegetal, frais, fruite
# CAS 109-15-9 ➜ added descriptors: lactique, vegetal_vert, vegetal, frais
# CAS 109-19-3 ➜ added descriptors: fruit_a_noyau, fruit_a_pepins, lactone, vegetal_vert, vegetal, frais, fruit_exotique
# CAS 109-20-6 ➜ added descriptors: aldehyde, peponide, fruit_a_pepins, vegetal_vert, vegetal, aldehyde_frais, frais, fruit_noir, baie, gras, fruit_exotique
# CAS 109-21-7 ➜ added descriptors: boissons_alcoolisees, boise, solvant, balsamique, alcool_de_fut, vegetal_vert, chimique, vegetal, fruit_noir, baie, fruit_rouge
# CAS 109-25-1 ➜ added descriptors: aldehyde, banane, vegetal_vert, vegetal, aldehyde_frais, frais, gras, fruit_exotique
# CAS 109-29-5 ➜ added descriptors: musque, boise, floral, mineral
# CAS 109-42-2 ➜ added descriptors: lactique, boissons_alcoolisees, aldehyde, fermentaire, boisson_fermentee, vegetal_vert, chimique, vegetal
# CAS 109-43-3 ➜ added descriptors: gras
# CAS 109-49-9 ➜ added descriptors: chimique, frais, solvant
# CAS 109-52-4 ➜ added descriptors: animal, vegetal, vegetal_sec, gras, fermentaire
# CAS 109-60-4 ➜ added descriptors: fruit_a_pepins, vegetal_vert, plante_aromatique, vegetal, chimique, frais, mielle, fruit_exotique, fruit_rouge
# CAS 109-73-9 ➜ added descriptors: amine, chimique
# CAS 109-79-5 ➜ added descriptors: empyreumatique, alliace, cuit, vegetal, legumes_cuits
# CAS 109-80-8 ➜ added descriptors: empyreumatique, cuit
# CAS 109-89-7 ➜ added descriptors: amine, chimique
# CAS 109-94-4 ➜ added descriptors: fleur_d_arbuste, boise, solvant, balsamique, boisson_fermentee, phenole, vegetal_vert, malte, boissons_alcoolisees, alcool_de_fut, medicinal, chimique, frais, floral, cereale, vegetal
# CAS 109-95-5 ➜ added descriptors: boissons_alcoolisees, boise, solvant, balsamique, alcool_de_fut, chimique, frais
# CAS 109-97-7 ➜ added descriptors: solvant, oleagineux, chimique, fruit_sec, frais, fruite, gras
# CAS 110-01-0 ➜ added descriptors: crucifere, vegetal, soufre, legume
# CAS 110-02-1 ➜ added descriptors: vegetal, soufre, legume
# CAS 110-19-0 ➜ added descriptors: solvant, fruit_a_pepins, chimique, frais
# CAS 110-38-3 ➜ added descriptors: gras, fruit_a_pepins
# CAS 110-39-4 ➜ added descriptors: lactique, fleur_d_arbuste, vegetal_vert, vegetal, floral, gras
# CAS 110-40-7 ➜ added descriptors: boise, balsamique, fruit_a_pepins, boisson_fermentee, fermentaire, vegetal_vert, plante_aromatique, doux, epice, boissons_alcoolisees, peponide, alcool_de_fut, chimique, vegetal, floral
# CAS 110-41-8 ➜ added descriptors: floral, metal, boise, vegetal_sec, balsamique, foret, vegetal_vert, mineral, doux, lactone, terreux, vegetal, fleur_du_jardin, fruite, soufre
# CAS 110-42-9 ➜ added descriptors: boisson_fermentee, chimique, boissons_alcoolisees, fermentaire
# CAS 110-43-0 ➜ added descriptors: lactique, aldehyde, vegetal_sec, balsamique, fermentaire, vegetal_vert, fruit_sec, gras, fruit_exotique, coumarine, oleagineux, lactone, vegetal, frais, aldehyde_frais
# CAS 110-45-2 ➜ added descriptors: boissons_alcoolisees, fruit_a_noyau, solvant, fermentaire, boisson_fermentee, fruit_a_pepins, vegetal_vert, chimique, vegetal, frais, floral, fruit_noir, baie
# CAS 110-58-7 ➜ added descriptors: amine, chimique
# CAS 110-62-3 ➜ added descriptors: lactique, boisson_fermentee, fruit_sec, doux, gras, empyreumatique, malte, boissons_alcoolisees, cuit, torrefie, oleagineux, cereale, chimique, lacte, floral
# CAS 110-66-7 ➜ added descriptors: empyreumatique, vegetal, cuit
# CAS 110-74-7 ➜ added descriptors: boissons_alcoolisees, boise, solvant, balsamique, alcool_de_fut, vegetal_vert, chimique, vegetal, frais, anise
# CAS 110-77-0 ➜ added descriptors: cuit, empyreumatique
# CAS 110-81-6 ➜ added descriptors: alliace, vegetal, soufre, legume
# CAS 110-85-0 ➜ added descriptors: amine, chimique
# CAS 110-86-1 ➜ added descriptors: amine, chimique
# CAS 110-93-0 ➜ added descriptors: citronne, lactique, legume_vert, fermentaire, fruit_a_pepins, vegetal_vert, plante_aromatique, vegetal, frais, fruit_exotique
# CAS 111-11-5 ➜ added descriptors: vegetal_vert, vegetal, frais, aldehyde_frais
# CAS 111-12-6 ➜ added descriptors: cucurbitacee, aldehyde, boise, fermentaire, vegetal_vert, moisi, peponide, terreux, vegetal, frais, fleur_du_jardin, aldehyde_frais
# CAS 111-13-7 ➜ added descriptors: aldehyde, fermentaire, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 111-14-8 ➜ added descriptors: animal, lactique, fruit_exotique
# CAS 111-26-2 ➜ added descriptors: amine, chimique, fermentaire
# CAS 111-27-3 ➜ added descriptors: solvant, phenole, chimique, medicinal, frais, vegetal_vert, vegetal, gras
# CAS 111-28-4 ➜ added descriptors: aldehyde, boise, balsamique, fermentaire, vegetal_vert, fruit_sec, gras, boissons_alcoolisees, amande_amere, oleagineux, alcool_de_fut, chimique, vegetal, frais, aldehyde_frais
# CAS 111-31-9 ➜ added descriptors: empyreumatique, cuit, oleagineux, fruit_sec, vegetal, chimique, fruite
# CAS 111-47-7 ➜ added descriptors: vegetal, soufre, legume
# CAS 111-55-7 ➜ added descriptors: solvant, phenole, chimique, medicinal, frais, vegetal_vert, vegetal, fruite
# CAS 111-62-6 ➜ added descriptors: animal, graisse_animale
# CAS 111-70-6 ➜ added descriptors: floral, fleur_d_arbuste, fruit_a_pepins, vegetal_vert, fruit_sec, fruit_exotique, oleagineux, chimique, vegetal, frais, fleur_du_jardin, aldehyde_frais
# CAS 111-71-7 ➜ added descriptors: boissons_alcoolisees, boise, balsamique, alcool_de_fut, vegetal_vert, plante_aromatique, vegetal, chimique, aldehyde_frais, epice, doux
# CAS 111-79-5 ➜ added descriptors: fleur_du_jardin, lactique, peponide, fruit_a_pepins, vegetal_vert, vegetal, frais, floral, gras
# CAS 111-80-8 ➜ added descriptors: fleur_du_jardin, cucurbitacee, aldehyde, peponide, vegetal_vert, vegetal, aldehyde_frais, frais, gras, legume
# CAS 111-81-9 ➜ added descriptors: fleur_d_arbuste, boise, moisi, fermentaire, fruite, fruit_exotique
# CAS 111-82-0 ➜ added descriptors: lactique, aldehyde, boise, vegetal_sec, balsamique, fermentaire, vegetal_vert, fruit_sec, doux, fruit_exotique, coumarine, moisi, oleagineux, lactone, terreux, vegetal, frais, fruite
# ...
# CAS 121199-28-8 ➜ added descriptors: vegetal_vert, aldehyde, vegetal, aldehyde_frais, frais
# CAS 121251-68-1 ➜ added descriptors: marin, balsamique, vegetal_vert, vegetal, frais, doux, gras
# CAS 122397-96-0 ➜ added descriptors: doux, boise, balsamique
# CAS 122440-59-9 ➜ added descriptors: metal, oleagineux, fruit_sec, mineral, fruite
# CAS 122760-84-3 ➜ added descriptors: citronne, frais, fruite, agrume
# CAS 122760-85-4 ➜ added descriptors: vegetal_vert, vegetal, doux, balsamique
# CAS 122795-41-9 ➜ added descriptors: aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, fruite, gras
# CAS 122861-78-3 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 124918-65-6 ➜ added descriptors: animal
# CAS 125037-13-0 ➜ added descriptors: citronne, fleur_d_arbuste, aldehyde, vegetal_sec, fleur_d_arbre, vegetal_vert, plante_aromatique, mielle, doux, vegetal, aldehyde_frais
# CAS 125109-84-4 ➜ added descriptors: vegetal_vert, chimique, vegetal, frais, peponide, fruite
# CAS 125109-85-5 ➜ added descriptors: fleur_d_arbre, vegetal_vert, vegetal, fleur_du_jardin
# CAS 125352-06-9 ➜ added descriptors: fleur_du_jardin, animal, phenole
# CAS 125476-24-6 ➜ added descriptors: empyreumatique, cuit, boise, balsamique, sucre_cuit
# CAS 125811-37-2 ➜ added descriptors: vegetal_vert, plante_aromatique, vegetal, frais
# CAS 127931-21-9 ➜ added descriptors: fruite, fruit_rouge
# CAS 128119-70-0 ➜ added descriptors: floral, doux, balsamique
# CAS 128342-71-2 ➜ added descriptors: animal, empyreumatique, cuit
# CAS 128342-72-3 ➜ added descriptors: animal, empyreumatique, cuit
# CAS 130786-09-3 ➜ added descriptors: mineral, metal, aldehyde, vegetal_vert, vegetal, frais, fleur_du_jardin, aldehyde_frais, gras
# CAS 131222-75-8 ➜ added descriptors: boise, vegetal_sec, balsamique, vegetal, frais, doux
# CAS 131222-76-9 ➜ added descriptors: empyreumatique, cuit, doux, sucre_cuit
# CAS 131766-73-9 ➜ added descriptors: aldehyde, vegetal_sec, vegetal_vert, plante_aromatique, vegetal, aldehyde_frais, frais, epice, gras
# CAS 131812-67-4 ➜ added descriptors: animal, musque, floral, doux, balsamique
# CAS 132735-95-6 ➜ added descriptors: animal
# CAS 133447-37-7 ➜ added descriptors: amine, empyreumatique
# CAS 133860-42-1 ➜ added descriptors: empyreumatique
# CAS 134123-93-6 ➜ added descriptors: aldehyde, vegetal_vert, chimique, vegetal, frais, aldehyde_frais, gras
# CAS 188590-62-7 ➜ added descriptors: mineral, metal, vegetal_vert, vegetal, frais, fruite, gras
# CAS 134769-33-8 ➜ added descriptors: agrume, vegetal_vert, vegetal, fruite, gras
# CAS 135910-94-0 ➜ added descriptors: lactique, metal, fruit_sec, doux, mineral, gras, empyreumatique, malte, oleagineux, torrefie, cacao, lacte, fruite
# CAS 136954-20-6 ➜ added descriptors: animal, empyreumatique, legume, cuit, alliace, fruit_a_pepins, fermentaire, vegetal_vert, vegetal, fruit_noir, fruit_rouge
# CAS 136954-21-7 ➜ added descriptors: empyreumatique
# CAS 136954-25-1 ➜ added descriptors: metal, fruit_a_noyau, vegetal_vert, plante_aromatique, mineral, animal, empyreumatique, alliace, cuit, lactone, chimique, vegetal, frais, legumes_cuits
# CAS 137085-37-1 ➜ added descriptors: fruite, fruit_rouge
# CAS 137255-07-3 ➜ added descriptors: moisi, fermentaire
# CAS 139164-92-4 ➜ added descriptors: empyreumatique, vegetal_vert, vegetal, frais, cuit
# CAS 139504-68-0 ➜ added descriptors: animal, musque, balsamique, vegetal_vert, vegetal, doux
# CAS 139539-66-5 ➜ added descriptors: aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 141773-73-1 ➜ added descriptors: animal, musque, fruit_a_pepins, vegetal_vert, vegetal
# CAS 142653-61-0 ➜ added descriptors: fleur_du_jardin, cucurbitacee, aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, legume
# CAS 142896-08-0 ➜ added descriptors: aldehyde, oleagineux, vegetal_vert, fruit_sec, vegetal, aldehyde_frais, frais, fruite, gras
# CAS 142896-09-1 ➜ added descriptors: floral, aldehyde, vegetal_vert, vegetal, aldehyde_frais, fleur_du_jardin, frais, gras
# CAS 142896-11-5 ➜ added descriptors: aldehyde, boise, balsamique, vegetal_vert, plante_aromatique, vegetal, aldehyde_frais, frais, gras
# CAS 142896-12-6 ➜ added descriptors: empyreumatique, aldehyde, vegetal_vert, vegetal, frais, aldehyde_frais, gras
# CAS 146955-45-5 ➜ added descriptors: fleur_du_jardin, fleur_d_arbuste, floral
# CAS 147159-48-6 ➜ added descriptors: cucurbitacee, aldehyde, vegetal_vert, vegetal, frais, aldehyde_frais, gras, legume
# CAS 147159-49-7 ➜ added descriptors: vegetal_vert, vegetal, fruite, gras
# CAS 149982-46-7 ➜ added descriptors: fleur_d_arbuste, floral, fruit_a_pepins
# CAS 154170-44-2 ➜ added descriptors: vegetal_vert, aldehyde, vegetal, aldehyde_frais, frais, gras
# CAS 154171-77-4 ➜ added descriptors: animal, musque, balsamique, vegetal_vert, vegetal, floral, doux
# CAS 155639-75-1 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 156472-94-5 ➜ added descriptors: empyreumatique
# CAS 157615-33-3 ➜ added descriptors: fermentaire
# CAS 163038-04-8 ➜ added descriptors: empyreumatique, lactique, malte, torrefie, fermentaire, cacao
# CAS 165191-91-3 ➜ added descriptors: vegetal_vert, aldehyde, vegetal, aldehyde_frais, frais
# CAS 166432-52-6 ➜ added descriptors: animal, fleur_du_jardin, vegetal_vert, vegetal, frais
# CAS 168564-54-3 ➜ added descriptors: terreux, fermentaire
# CAS 169054-69-7 ➜ added descriptors: aldehyde, vegetal_vert, mielle, vegetal, aldehyde_frais, doux, frais
# CAS 172201-58-0 ➜ added descriptors: lactone, fruit_a_noyau
# CAS 180031-78-1 ➜ added descriptors: cuit, empyreumatique
# CAS 180964-47-0 ➜ added descriptors: boise, balsamique, vegetal_vert, plante_aromatique, vegetal, frais, doux
# CAS 181258-87-7 ➜ added descriptors: legume_vert, vert_pyrazique, vegetal_vert, chimique, vegetal, frais, legume
# CAS 182699-77-0 ➜ added descriptors: boise, vegetal_sec, balsamique, vegetal_vert, fruit_sec, plante_aromatique, anise, gras, fruit_exotique, coumarine, oleagineux, lactone, vegetal, frais, fruite
# CAS 185429-83-8 ➜ added descriptors: doux, balsamique
# CAS 188417-26-7 ➜ added descriptors: lactique, boise, empyreumatique, malte, boissons_alcoolisees, cuit, torrefie, alcool_de_fut, cacao, chimique, floral, sucre_cuit
# CAS 188570-78-7 ➜ added descriptors: vegetal_vert, vegetal, fruite
# CAS 189440-77-5 ➜ added descriptors: vegetal_vert, vegetal, frais, fruit_a_pepins
# CAS 194934-66-2 ➜ added descriptors: fleur_du_jardin, vegetal_vert, lactique, vegetal, frais
# CAS 195863-84-4 ➜ added descriptors: vegetal_vert, plante_aromatique, vegetal, frais
# CAS 196109-18-9 ➜ added descriptors: fleur_du_jardin, cucurbitacee, aldehyde, peponide, fruit_a_pepins, vegetal_vert, vegetal, aldehyde_frais, floral, frais, gras, legume
# CAS 198404-98-7 ➜ added descriptors: animal, bois, musque, aldehyde, fruite, balsamique, vegetal_vert, plante_aromatique, vegetal, aldehyde_frais, frais, doux
# CAS 202188-43-0 ➜ added descriptors: vegetal_vert, chimique, vegetal, frais, solvant, fermentaire
# CAS 203719-54-4 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 211238-85-6 ➜ added descriptors: fleur_du_jardin
# CAS 211299-54-6 ➜ added descriptors: bois, balsamique, resineux, vegetal, doux
# CAS 211323-05-6 ➜ added descriptors: vegetal_vert, peponide, vegetal, fruit_a_pepins
# CAS 215231-33-7 ➜ added descriptors: fleur_du_jardin, floral, fruite
# CAS 224031-70-3 ➜ added descriptors: vegetal_vert, vegetal, frais, fruit_exotique
# CAS 227456-27-1 ➜ added descriptors: mineral, empyreumatique, metal, vegetal, legume
# CAS 227456-28-2 ➜ added descriptors: animal, empyreumatique, poulailler, vegetal, fruite, legume
# CAS 227456-33-9 ➜ added descriptors: empyreumatique, cuit, alliace, vegetal, legume
# CAS 233665-90-2 ➜ added descriptors: fruit_a_pepins
# CAS 233665-96-8 ➜ added descriptors: lactique, vegetal, fermentaire
# CAS 236391-76-7 ➜ added descriptors: animal, vegetal_vert, vegetal, musque
# CAS 252736-36-0 ➜ added descriptors: vegetal, legume
# CAS 252736-39-3 ➜ added descriptors: empyreumatique, vegetal, alliace, cuit, legume
# CAS 252736-41-7 ➜ added descriptors: empyreumatique, cuit
# CAS 259854-70-1 ➜ added descriptors: frais, floral, musque
# CAS 259854-71-2 ➜ added descriptors: animal, musque
# CAS 285977-85-7 ➜ added descriptors: fleur_du_jardin
# CAS 292605-05-1 ➜ added descriptors: legume_vert, vert_pyrazique, racine, fruit_a_pepins, crucifere, terreux, vegetal_vert, vegetal, fruite, soufre, legume
# CAS 300371-33-9 ➜ added descriptors: floral, vegetal_vert, vegetal, fleur_du_jardin, gras
# CAS 307964-23-4 ➜ added descriptors: vegetal_vert, vegetal, frais, fruit_noir, baie, fruit_exotique
# CAS 307964-33-6 ➜ added descriptors: vegetal_vert, vegetal, aldehyde_frais, frais, gras
# CAS 308805-43-8 ➜ added descriptors: empyreumatique, lactique, cuit, fermentaire
# CAS 313973-37-4 ➜ added descriptors: floral, mineral, metal, aldehyde, vegetal_vert, vegetal, aldehyde_frais, fleur_du_jardin, frais, gras
# CAS 317803-03-5 ➜ added descriptors: empyreumatique, oleagineux, fruit_sec, pyrazique, fruite, gras
# CAS 319002-92-1 ➜ added descriptors: citronne, bois, boise, agrume, vegetal_vert, plante_aromatique, vegetal, frais, fruite
# CAS 338735-71-0 ➜ added descriptors: terreux, doux, moisi, balsamique, fermentaire
# CAS 357650-26-1 ➜ added descriptors: fleur_d_arbuste, fruit_a_noyau, fruit_a_pepins, floral
# CAS 35931-93-2 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 359794-78-8 ➜ added descriptors: fermentaire
# CAS 676125-00-1 ➜ added descriptors: animal, vegetal_sec, balsamique, vegetal_vert, vegetal, floral, doux
# CAS 400052-49-5 ➜ added descriptors: aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais
# CAS 437770-28-0 ➜ added descriptors: citronne, vegetal_vert, plante_aromatique, vegetal, frais, fruite
# CAS 444880-09-5 ➜ added descriptors: floral, aldehyde, alliace, vegetal_vert, plante_aromatique, vegetal, frais, fleur_du_jardin, aldehyde_frais, gras, legume
# CAS 473438-39-0 ➜ added descriptors: vegetal_vert, vegetal, frais
# CAS 476332-65-7 ➜ added descriptors: musque
# CAS 477218-42-1 ➜ added descriptors: animal, musque
# CAS 478695-70-4 ➜ added descriptors: animal, lactique, musque, floral, fruit_a_pepins
# CAS 479547-57-4 ➜ added descriptors: bois, aldehyde, boise, peponide, resineux, phenole, vegetal_vert, vegetal, frais, aldehyde_frais, fruite, gras
# CAS 544409-58-7 ➜ added descriptors: chimique, vegetal, vegetal_sec, soufre
# CAS 548774-80-7 ➜ added descriptors: fruit_a_noyau, vegetal_sec, agrume, lactone, vegetal
# CAS 597532-53-1 ➜ added descriptors: fleur_d_arbuste, vegetal_vert, plante_aromatique, vegetal, floral
# CAS 597550-02-2 ➜ added descriptors: mineral, doux, metal, fruit_a_pepins
# CAS 686298-93-1 ➜ added descriptors: empyreumatique
# CAS 723759-62-4 ➜ added descriptors: fruit_sec, gras, oleagineux
# CAS 737776-59-9 ➜ added descriptors: floral, citronne, agrume, vegetal_vert, vegetal, frais, fleur_du_jardin, gras
# CAS 737776-68-0 ➜ added descriptors: vegetal_vert, chimique, vegetal, frais, epice
# CAS 744251-93-2 ➜ added descriptors: empyreumatique
# CAS 745047-51-2 ➜ added descriptors: cuit, empyreumatique
# CAS 745047-53-4 ➜ added descriptors: cuit, empyreumatique
# CAS 745047-94-3 ➜ added descriptors: cuit, empyreumatique
# CAS 745047-97-6 ➜ added descriptors: cuit, empyreumatique
# CAS 782498-03-7 ➜ added descriptors: empyreumatique
# CAS 791807-20-0 ➜ added descriptors: empyreumatique
# CAS 796857-79-9 ➜ added descriptors: vegetal_vert, aldehyde, vegetal, aldehyde_frais, frais, gras
# CAS 815580-59-7 ➜ added descriptors: fleur_d_arbuste, epice
# CAS 828300-39-6 ➜ added descriptors: alliace, fruit_exotique, agrume, vegetal, fruit_noir, baie, fruite, soufre, legume
# CAS 847144-75-6 ➜ added descriptors: empyreumatique, fleur_d_arbuste, boissons_alcoolisees, cuit, fruit_a_noyau, boise, balsamique, alcool_de_fut, chimique, doux, floral, sucre_cuit
# CAS 851669-60-8 ➜ added descriptors: lactique
# CAS 851768-51-9 ➜ added descriptors: fruit_a_noyau, peponide, lactone, vegetal_vert, vegetal, frais, fruite
# CAS 852997-30-9 ➜ added descriptors: empyreumatique, lactique, legume_vert, cuit, racine, oleagineux, crucifere, terreux, fruit_sec, vegetal, fruite, soufre, legume
# CAS 871465-49-5 ➜ added descriptors: epice, bois, menthe, boise, phenole, medicinal, vegetal, chimique, vegetal_vert, fruit_noir, baie, frais, plante_aromatique, anise
# CAS 873888-84-7 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, frais
# CAS 1094004-39-3 ➜ added descriptors: vegetal, alliace, soufre, legume
# CAS 915971-43-6 ➜ added descriptors: cuit, empyreumatique
# CAS 917750-72-2 ➜ added descriptors: fleur_d_arbuste, floral
# CAS 923593-56-0 ➜ added descriptors: chimique, frais, solvant
# CAS 929253-05-4 ➜ added descriptors: vegetal_vert, chimique, vegetal, frais
# CAS 934534-30-2 ➜ added descriptors: vegetal_vert, vegetal, fruite, gras
# CAS 950919-28-5 ➜ added descriptors: frais
# CAS 958660-02-1 ➜ added descriptors: cuit, empyreumatique
# CAS 977091-24-9 ➜ added descriptors: phenole, medicinal, chimique, epice, boise
# CAS 1006684-20-3 ➜ added descriptors: soufre, crucifere, vegetal
# CAS 1009814-14-5 ➜ added descriptors: doux, boise
# CAS 1023288-21-2 ➜ added descriptors: vegetal_vert, chimique, vegetal, gras, soufre
# CAS 1064678-08-5 ➜ added descriptors: viande_fumee, lactique, fruit_a_pepins, fleur_d_arbre, phenole, vegetal_vert, mielle, fruit_exotique, legume, empyreumatique, peponide, fume, vegetal, floral, soufre
# CAS 1160112-20-8 ➜ added descriptors: mineral, metal
# CAS 1190230-47-7 ➜ added descriptors: cuit, empyreumatique
# CAS 1225070-56-3 ➜ added descriptors: aldehyde, vegetal_vert, vegetal, aldehyde_frais, frais, fruite, gras
# CAS 1241905-19-0 ➜ added descriptors: lactique, aldehyde, boise, fermentaire, vegetal_vert, doux, gras, empyreumatique, malte, moisi, torrefie, cacao, terreux, lacte, vegetal, aldehyde_frais, frais, fruite
# CAS 1247790-47-1 ➜ added descriptors: vegetal_vert, vegetal, fleur_d_arbuste, frais
# CAS 1271488-66-4 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, fleur_d_arbuste, frais
# CAS 1304037-63-5 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, frais, floral
# CAS 1304037-68-0 ➜ added descriptors: fleur_du_jardin, vegetal_vert, vegetal, frais, floral
# CAS 1314926-27-6 ➜ added descriptors: empyreumatique, cuit, oleagineux, viande_cuite, fruit_sec, fruite, gras
# CAS 1315251-11-6 ➜ added descriptors: animal, musque, boise, balsamique, doux
# CAS 1339119-15-1 ➜ added descriptors: vegetal_vert, vegetal, frais, fleur_du_jardin
# CAS 1378867-81-2 ➜ added descriptors: vegetal_vert, vegetal, frais, fleur_du_jardin, gras
# CAS 1416051-88-1 ➜ added descriptors: boise, fruit_a_pepins, fermentaire, fruit_sec, gras, empyreumatique, cuit, moisi, oleagineux, agrume, terreux, fruite, soufre
# CAS 1658479-63-0 ➜ added descriptors: legume, empyreumatique, legume_vert, vert_pyrazique, cuit, sucre_cuit, vegetal_vert, vegetal, fruit_cuit, doux, frais, fruite, fruit_rouge
#
# Log saved.
#
# === New Columns Added to the CSV ===
# alcool_blanc
# alcool_de_fut
# aldehyde_frais
# amine
# biscuit
# bois
# boisson_fermentee
# boissons_alcoolisees
# cereale_torrefiee
# citronne
# crucifere
# cucurbitacee
# empyreumatique
# fleur_d_arbre
# fleur_d_arbuste
# fleur_du_jardin
# fruit_a_coque_torrefie
# fruit_a_noyau
# fruit_a_pepins
# fruit_cuit
# fruit_noir
# fruit_rouge
# fume
# graisse_animale
# legume_vert
# legumes_cuits
# metal
# mielle
# mineral
# musque
# oleagineux
# patisserie
# peponide
# pied
# plante_aromatique
# pyrazique
# sucre_cuit
# vegetal
# vegetal_sec
# vegetal_vert
# vert_pyrazique
# zeste
#
# Total new descriptor columns added: 42
# List of new descriptor columns:
#  ['alcool_blanc', 'alcool_de_fut', 'aldehyde_frais', 'amine', 'biscuit', 'bois', 'boisson_fermentee', 'boissons_alcoolisees', 'cereale_torrefiee', 'citronne', 'crucifere', 'cucurbitacee', 'empyreumatique', 'fleur_d_arbre', 'fleur_d_arbuste', 'fleur_du_jardin', 'fruit_a_coque_torrefie', 'fruit_a_noyau', 'fruit_a_pepins', 'fruit_cuit', 'fruit_noir', 'fruit_rouge', 'fume', 'graisse_animale', 'legume_vert', 'legumes_cuits', 'metal', 'mielle', 'mineral', 'musque', 'oleagineux', 'patisserie', 'peponide', 'pied', 'plante_aromatique', 'pyrazique', 'sucre_cuit', 'vegetal', 'vegetal_sec', 'vegetal_vert', 'vert_pyrazique', 'zeste']

# %% [markdown]
# ### Print newly added Descriptors Columns

# %%
import textwrap

# Load the files for comaparision
original_df = pd.read_csv("C:/Users/suman/OneDrive/Bureau/Internship_Study/GNN_On_OdorPrediction/data/raw_data/OdorCAS_preprocessed.csv")
enriched_df = pd.read_csv("Hierarchy_OdorCAS.csv")

# Get descriptor columns (excluding the cas_number column)
original_cols = set(original_df.columns) - {"cas_number"}
enriched_cols = set(enriched_df.columns) - {"cas_number"}

# Find newly added descriptors
new_descriptors = sorted(enriched_cols - original_cols)

# Output
print(f"Number of new descriptors added: {len(new_descriptors)}")
print("Newly added descriptor columns:")

output = textwrap.fill(", ".join(new_descriptors), width=100)
print(output)
# Out:
# Number of new descriptors added: 42
# Newly added descriptor columns:
# alcool_blanc, alcool_de_fut, aldehyde_frais, amine, biscuit, bois, boisson_fermentee,
# boissons_alcoolisees, cereale_torrefiee, citronne, crucifere, cucurbitacee, empyreumatique,
# fleur_d_arbre, fleur_d_arbuste, fleur_du_jardin, fruit_a_coque_torrefie, fruit_a_noyau,
# fruit_a_pepins, fruit_cuit, fruit_noir, fruit_rouge, fume, graisse_animale, legume_vert,
# legumes_cuits, metal, mielle, mineral, musque, oleagineux, patisserie, peponide, pied,
# plante_aromatique, pyrazique, sucre_cuit, vegetal, vegetal_sec, vegetal_vert, vert_pyrazique, zeste
