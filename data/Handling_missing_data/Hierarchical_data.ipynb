# %%
import pandas as pd
from rdflib import Graph, RDFS, URIRef, RDF
from collections import defaultdict

# %% [markdown]
# #### Saturate Data with RDF Graph

# %%
# Load RDF Graph
g = Graph()
g.parse("graph_odor.ttl", format="ttl")

# Build Subclass Hierarchy: child -> set of parents
subclass_map = defaultdict(set)
instance_map = defaultdict(set)

for child, _, parent in g.triples((None, RDFS.subClassOf, None)):
    child_label = child.split('#')[-1].split('/')[-1].lower()
    parent_label = parent.split('#')[-1].split('/')[-1].lower()
    subclass_map[child_label].add(parent_label)

# Map individuals to classes
for instance, _, cls in g.triples((None, RDF.type, None)):
    if cls != RDFS.Class:  # <-- skip RDF class declarations
        instance_label = instance.split('#')[-1].split('/')[-1].lower()
        class_label = cls.split('#')[-1].split('/')[-1].lower()
        instance_map[instance_label].add(class_label)

# Recursively find all ancestors
def get_all_parents(term, visited=None):
    if visited is None:
        visited = set()
    for parent in subclass_map.get(term, []):
        if parent not in visited:
            visited.add(parent)
            get_all_parents(parent, visited)
    return visited

# Load CSV
df = pd.read_csv("C:/Users/suman/OneDrive/Bureau/Internship_Study/GNN_On_OdorPrediction/data/Handling_missing_data/SoS_Top138_updated.csv")
df.columns = [col.lower() for col in df.columns]

# Get list of descriptor columns (excluding 'cas_number')
descriptor_cols = list(df.columns)
descriptor_cols.remove("cas_number")

# Track Update
all_new_descriptors = set()
modifications_log = []
total_added_descriptors = 0
total_modified_cas = 0
excluded_descriptors = {"odeur"}

# Enrich Descriptors Per Row
for index, row in df.iterrows():
    cas_number = row["cas_number"]
    active_descriptors = {col for col in descriptor_cols if row[col] == 1}
    enriched_descriptors = set()

    # Get all parent descriptors for each active descriptor
    for desc in active_descriptors:
        # 1. Add class parents
        enriched_descriptors.update(get_all_parents(desc))

        # 2. Add rdf:type class if desc is an instance
        for parent_class in instance_map.get(desc, []):
            enriched_descriptors.add(parent_class)
            enriched_descriptors.update(get_all_parents(parent_class))

    # List of newly added descriptors
    added_descriptors = []
    for new_desc in enriched_descriptors:
        if new_desc not in excluded_descriptors:  # Skip excluded descriptors
            if new_desc not in df.columns:
                all_new_descriptors.add(new_desc)
                df[new_desc] = 0  # Initialize new column with 0
                
            # If the descriptor wasn't already set to 1, set it to 1
            if df.at[index, new_desc] == 0:
                df.at[index, new_desc] = 1
                added_descriptors.append(new_desc)

    # Log modification if any new descriptors were added
    if added_descriptors:
        modifications_log.append({
            "cas_number": cas_number,
            "new_descriptors_added": added_descriptors
        })
        total_added_descriptors += len(added_descriptors)
        total_modified_cas += 1

# Save the updated CSV
df.to_csv("Hierarchy_OdorCAS.csv", index=False)
print("Updated 'OdorCAS_preprocessed.csv'")

# Show the modification summary
print(f"\nNumber of CAS modified: {total_modified_cas}")
print(f"Number of descriptors added: {total_added_descriptors}")

# Show and save modification log if any changes were made
if modifications_log:
    print("\n ----- Modification Summary -----")
    for entry in modifications_log:
        print(f"CAS {entry['cas_number']} ➜ added descriptors: {', '.join(entry['new_descriptors_added'])}")
    
    # Save the log to a file
    log_df = pd.DataFrame(modifications_log)
    log_df.to_csv("LOG_label_added.csv", index=False)
    print("\nLog saved.")
else:
    print("\nNo changes were made to descriptors.")


if all_new_descriptors:
    print("\n ---- New Columns Added to the CSV ----")
    for col in sorted(all_new_descriptors):
        print(col)
    print(f"\nTotal new descriptor columns added: {len(all_new_descriptors)}")
else:
    print("\nNo new columns were added to the CSV.")

new_descriptor_list = sorted(all_new_descriptors)
print("List of new descriptor columns:\n", new_descriptor_list)
# Out:
# Updated 'OdorCAS_preprocessed.csv'
#
# Number of CAS modified: 113
# Number of descriptors added: 140
#
#  ----- Modification Summary -----
# CAS 1197-01-9 ➜ added descriptors: plante_aromatique
# CAS 98-85-1 ➜ added descriptors: plante_aromatique
# CAS 125-12-2 ➜ added descriptors: plante_aromatique
# CAS 78-59-1 ➜ added descriptors: plante_aromatique
# CAS 13341-72-5 ➜ added descriptors: plante_aromatique
# CAS 16409-43-1 ➜ added descriptors: plante_aromatique
# CAS 2756-56-1 ➜ added descriptors: plante_aromatique
# CAS 23550-40-5 ➜ added descriptors: baie, fruit_noir
# CAS 85586-67-0 ➜ added descriptors: plante_aromatique
# CAS 1618-26-4 ➜ added descriptors: empyreumatique, cuit
# CAS 76-49-3 ➜ added descriptors: plante_aromatique
# CAS 472-66-2 ➜ added descriptors: plante_aromatique
# CAS 80-56-8 ➜ added descriptors: plante_aromatique
# CAS 562-74-3 ➜ added descriptors: plante_aromatique
# CAS 60047-17-8 ➜ added descriptors: plante_aromatique
# CAS 13679-72-6 ➜ added descriptors: plante_aromatique
# CAS 7779-73-9 ➜ added descriptors: plante_aromatique
# CAS 93-58-3 ➜ added descriptors: plante_aromatique
# CAS 20347-65-3 ➜ added descriptors: plante_aromatique
# CAS 3387-41-5 ➜ added descriptors: plante_aromatique
# CAS 23283-97-8 ➜ added descriptors: plante_aromatique
# CAS 59323-76-1 ➜ added descriptors: baie, fruit_noir
# CAS 68527-77-5 ➜ added descriptors: plante_aromatique
# CAS 87-19-4 ➜ added descriptors: plante_aromatique
# CAS 82461-14-1 ➜ added descriptors: plante_aromatique
# CAS 24717-86-0 ➜ added descriptors: plante_aromatique
# CAS 32974-92-8 ➜ added descriptors: cuit
# CAS 495-40-9 ➜ added descriptors: plante_aromatique
# CAS 2294-76-0 ➜ added descriptors: cuit, empyreumatique
# CAS 28043-10-9 ➜ added descriptors: plante_aromatique
# CAS 851768-51-9 ➜ added descriptors: baie, fruit_noir
# CAS 507-70-0 ➜ added descriptors: plante_aromatique
# CAS 3583-00-4 ➜ added descriptors: plante_aromatique
# CAS 57576-09-7 ➜ added descriptors: plante_aromatique
# CAS 5331-32-8 ➜ added descriptors: plante_aromatique
# CAS 13877-93-5 ➜ added descriptors: plante_aromatique
# CAS 7549-41-9 ➜ added descriptors: plante_aromatique
# CAS 16587-71-6 ➜ added descriptors: plante_aromatique
# CAS 53475-15-3 ➜ added descriptors: baie, fruite, fruit_noir
# CAS 6413-26-9 ➜ added descriptors: plante_aromatique
# CAS 617-01-6 ➜ added descriptors: plante_aromatique
# CAS 5406-58-6 ➜ added descriptors: plante_aromatique
# CAS 59354-71-1 ➜ added descriptors: baie, fruit_noir
# CAS 464-43-7 ➜ added descriptors: plante_aromatique
# CAS 78-93-3 ➜ added descriptors: plante_aromatique
# CAS 10484-09-0 ➜ added descriptors: plante_aromatique
# CAS 105463-44-3 ➜ added descriptors: plante_aromatique
# CAS 4948-28-1 ➜ added descriptors: plante_aromatique
# CAS 119-53-9 ➜ added descriptors: plante_aromatique
# CAS 20298-72-0 ➜ added descriptors: plante_aromatique
# CAS 5986-55-0 ➜ added descriptors: plante_aromatique
# CAS 473-62-1 ➜ added descriptors: plante_aromatique
# CAS 18358-53-7 ➜ added descriptors: plante_aromatique
# CAS 76-50-6 ➜ added descriptors: plante_aromatique
# CAS 100-42-5 ➜ added descriptors: soufre
# CAS 97890-13-6 ➜ added descriptors: fleur_du_jardin
# CAS 1901-38-8 ➜ added descriptors: plante_aromatique
# CAS 3623-52-7 ➜ added descriptors: plante_aromatique
# CAS 90-02-8 ➜ added descriptors: plante_aromatique
# CAS 72402-00-7 ➜ added descriptors: plante_aromatique
# CAS 29414-56-0 ➜ added descriptors: plante_aromatique
# CAS 28977-58-4 ➜ added descriptors: plante_aromatique
# CAS 58096-46-1 ➜ added descriptors: plante_aromatique
# CAS 5287-45-6 ➜ added descriptors: cuit
# CAS 51755-83-0 ➜ added descriptors: baie, fruit_noir
# CAS 90-12-0 ➜ added descriptors: plante_aromatique
# CAS 18479-49-7 ➜ added descriptors: plante_aromatique
# CAS 67634-22-4 ➜ added descriptors: plante_aromatique
# CAS 52363-24-3 ➜ added descriptors: plante_aromatique
# CAS 19872-52-7 ➜ added descriptors: baie, fruit_noir
# CAS 56836-93-2 ➜ added descriptors: plante_aromatique
# CAS 465-31-6 ➜ added descriptors: plante_aromatique
# CAS 1901-26-4 ➜ added descriptors: plante_aromatique
# CAS 38284-11-6 ➜ added descriptors: plante_aromatique
# CAS 60362-71-2 ➜ added descriptors: plante_aromatique
# CAS 61837-77-2 ➜ added descriptors: cuit, empyreumatique
# CAS 85248-56-2 ➜ added descriptors: plante_aromatique
# CAS 5834-16-2 ➜ added descriptors: cuit, plante_aromatique, empyreumatique
# CAS 67715-80-4 ➜ added descriptors: baie, fruit_noir
# CAS 22094-00-4 ➜ added descriptors: doux
# CAS 3289-28-9 ➜ added descriptors: doux
# CAS 29606-79-9 ➜ added descriptors: plante_aromatique
# CAS 89-47-4 ➜ added descriptors: plante_aromatique
# CAS 76-22-2 ➜ added descriptors: plante_aromatique
# CAS 464-48-2 ➜ added descriptors: plante_aromatique
# CAS 63458-78-6 ➜ added descriptors: baie, fruit_noir
# CAS 471-84-1 ➜ added descriptors: plante_aromatique
# CAS 108-93-0 ➜ added descriptors: plante_aromatique
# CAS 128-37-0 ➜ added descriptors: plante_aromatique
# CAS 59324-17-3 ➜ added descriptors: baie, fruit_noir
# CAS 7779-77-3 ➜ added descriptors: fleur_d_arbre
# CAS 1197-07-5 ➜ added descriptors: plante_aromatique
# CAS 100-68-5 ➜ added descriptors: cuit
# CAS 14252-42-7 ➜ added descriptors: cuit
# CAS 134-09-8 ➜ added descriptors: plante_aromatique
# CAS 105-45-3 ➜ added descriptors: doux
# CAS 628-29-5 ➜ added descriptors: cuit, empyreumatique
# CAS 541-31-1 ➜ added descriptors: cuit, empyreumatique
# CAS 1639-09-4 ➜ added descriptors: cuit, empyreumatique
# CAS 34619-12-0 ➜ added descriptors: cuit, empyreumatique
# CAS 40790-04-3 ➜ added descriptors: cuit, empyreumatique
# CAS 110-01-0 ➜ added descriptors: cuit, empyreumatique
# CAS 23769-39-3 ➜ added descriptors: cuit, empyreumatique, baie, fruite, fruit_noir
# CAS 59259-38-0 ➜ added descriptors: plante_aromatique
# CAS 68489-14-5 ➜ added descriptors: plante_aromatique
# CAS 499-74-1 ➜ added descriptors: plante_aromatique
# CAS 32449-92-6 ➜ added descriptors: plante_aromatique
# CAS 491-02-1 ➜ added descriptors: plante_aromatique
# CAS 96-08-2 ➜ added descriptors: plante_aromatique
# CAS 2102-59-2 ➜ added descriptors: plante_aromatique
# CAS 13679-85-1 ➜ added descriptors: fruit_noir
# CAS 55764-22-2 ➜ added descriptors: cuit, empyreumatique
# CAS 18362-97-5 ➜ added descriptors: doux
#
# Log saved.
#
# No new columns were added to the CSV.
# List of new descriptor columns:
#  []

# %% [markdown]
# ### Print newly added Descriptors Columns

# %%
import textwrap

# Load the files for comaparision
original_df = pd.read_csv("C:/Users/suman/OneDrive/Bureau/Internship_Study/GNN_On_OdorPrediction/data/raw_data/OdorCAS_preprocessed.csv")
enriched_df = pd.read_csv("Hierarchy_OdorCAS.csv")

# Get descriptor columns (excluding the cas_number column)
original_cols = set(original_df.columns) - {"cas_number"}
enriched_cols = set(enriched_df.columns) - {"cas_number"}

# Find newly added descriptors
new_descriptors = sorted(enriched_cols - original_cols)

# Output
print(f"Number of new descriptors added: {len(new_descriptors)}")
print("Newly added descriptor columns:")

output = textwrap.fill(", ".join(new_descriptors), width=100)
print(output)
# Out:
# Number of new descriptors added: 42
# Newly added descriptor columns:
# alcool_blanc, alcool_de_fut, aldehyde_frais, amine, biscuit, bois, boisson_fermentee,
# boissons_alcoolisees, cereale_torrefiee, citronne, crucifere, cucurbitacee, empyreumatique,
# fleur_d_arbre, fleur_d_arbuste, fleur_du_jardin, fruit_a_coque_torrefie, fruit_a_noyau,
# fruit_a_pepins, fruit_cuit, fruit_noir, fruit_rouge, fume, graisse_animale, legume_vert,
# legumes_cuits, metal, mielle, mineral, musque, oleagineux, patisserie, peponide, pied,
# plante_aromatique, pyrazique, sucre_cuit, vegetal, vegetal_sec, vegetal_vert, vert_pyrazique, zeste
